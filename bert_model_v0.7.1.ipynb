# %%
from sentiment import utils


DATASET_DIR = './goemotions_data/'
classes = utils.load_classes(DATASET_DIR)
classes.remove('neutral')
classes
# Out:
# ['admiration',
#  'amusement',
#  'anger',
#  'annoyance',
#  'approval',
#  'caring',
#  'confusion',
#  'curiosity',
#  'desire',
#  'disappointment',
#  'disapproval',
#  'disgust',
#  'embarrassment',
#  'excitement',
#  'fear',
#  'gratitude',
#  'grief',
#  'joy',
#  'love',
#  'nervousness',
#  'optimism',
#  'pride',
#  'realization',
#  'relief',
#  'remorse',
#  'sadness',
#  'surprise']

# %%
# %%time
train_df, val_df, test_df = utils.make_dataframes(DATASET_DIR,
                                                  fraction=0.85,
                                                  random=1681944339,
                                                  split_by_class=True,
                                                  drop_neutral=True,
                                                  test_only_singles=True,
                                                  oversample_low=True,
                                                  low_threshold=500)
# Out:
# Random seed: 1682284394
# CPU times: total: 1.05 s
# Wall time: 1.05 s
# D:\sentiment-analysis\sentiment\utils.py:116: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   class_mask = (df['labels'].str.contains(f'(^|,){label}(,|$)',

# %%
from tensorflow.data import AUTOTUNE

BATCH_SIZE = 64


dataframes = {'Train': train_df, 'Validation': val_df, 'Test': test_df}
for title, df in dataframes.items():
    utils.plot_class_distr(df, classes, title)
train_ds = utils.make_ts_ds(train_df, classes, BATCH_SIZE, AUTOTUNE)
val_ds = utils.make_ts_ds(val_df, classes, BATCH_SIZE, AUTOTUNE)
test_ds = utils.make_ts_ds(test_df, classes, BATCH_SIZE, AUTOTUNE)
# Out:
# D:\sentiment-analysis\sentiment\utils.py:568: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(classes, rotation=45, ha='right')

# %%
from sentiment import bert_model

BERT_MODEL = 'small_bert/bert_en_uncased_L-2_H-128_A-2'


model = bert_model.BertSentimentModel(BERT_MODEL, dropout_rate=0.4,
                                      dense_units=256, classes=classes)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
from official.nlp import optimization  # to create AdamW optimizer
import tensorflow as tf
from tensorflow.keras.losses import BinaryCrossentropy


THRESHOLD = 0.5
EPOCHS = 10
INIT_LR = 3e-4


steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
num_train_steps = steps_per_epoch * EPOCHS
num_warmup_steps = int(0.1*num_train_steps)
optimizer = optimization.create_optimizer(init_lr=INIT_LR,
                                          num_train_steps=num_train_steps,
                                          num_warmup_steps=num_warmup_steps,
                                          optimizer_type='adamw')
metrics = utils.create_metrics(classes, THRESHOLD)
loss = BinaryCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
from tensorflow.keras.callbacks import EarlyStopping


history = model.fit(x=train_ds, validation_data=val_ds, epochs=EPOCHS,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=2)])
# Out:
# Epoch 1/10
# 463/463 [==============================] - 632s 1s/step - loss: 0.3110 - precision@0.5/admiration: 0.1742 - recall@0.5/admiration: 0.1173 - precision@0.5/amusement: 0.0838 - recall@0.5/amusement: 0.1339 - precision@0.5/anger: 0.0495 - recall@0.5/anger: 0.1617 - precision@0.5/annoyance: 0.0926 - recall@0.5/annoyance: 0.0782 - precision@0.5/approval: 0.1063 - recall@0.5/approval: 0.0218 - precision@0.5/caring: 0.0353 - recall@0.5/caring: 0.0314 - precision@0.5/confusion: 0.0436 - recall@0.5/confusion: 0.1877 - precision@0.5/curiosity: 0.0676 - recall@0.5/curiosity: 0.1511 - precision@0.5/desire: 0.0167 - recall@0.5/desire: 0.0275 - precision@0.5/disappointment: 0.0474 - recall@0.5/disappointment: 0.0888 - precision@0.5/disapproval: 0.0648 - recall@0.5/disapproval: 0.1355 - precision@0.5/disgust: 0.0174 - recall@0.5/disgust: 0.0740 - precision@0.5/embarrassment: 0.0174 - recall@0.5/embarrassment: 0.1423 - precision@0.5/excitement: 0.0157 - recall@0.5/excitement: 0.0560 - precision@0.5/fear: 0.0180 - recall@0.5/fear: 0.1294 - precision@0.5/gratitude: 0.1156 - recall@0.5/gratitude: 0.2249 - precision@0.5/grief: 0.0170 - recall@0.5/grief: 0.1022 - precision@0.5/joy: 0.0473 - recall@0.5/joy: 0.1246 - precision@0.5/love: 0.0774 - recall@0.5/love: 0.1338 - precision@0.5/nervousness: 0.0268 - recall@0.5/nervousness: 0.0321 - precision@0.5/optimism: 0.0545 - recall@0.5/optimism: 0.0459 - precision@0.5/pride: 0.0290 - recall@0.5/pride: 0.0277 - precision@0.5/realization: 0.0351 - recall@0.5/realization: 0.0249 - precision@0.5/relief: 0.0181 - recall@0.5/relief: 0.0359 - precision@0.5/remorse: 0.0160 - recall@0.5/remorse: 0.0615 - precision@0.5/sadness: 0.0448 - recall@0.5/sadness: 0.0634 - precision@0.5/surprise: 0.0325 - recall@0.5/surprise: 0.0856 - precision@0.5/all: 0.0554 - recall@0.5/all: 0.1054 - f1_score@0.5/all: 0.0771 - f1_score_micro@0.5/all: 0.0726 - f1_score_macro@0.5/all: 0.0577 - val_loss: 0.1430 - val_precision@0.5/admiration: 0.9048 - val_recall@0.5/admiration: 0.1121 - val_precision@0.5/amusement: 0.0000e+00 - val_recall@0.5/amusement: 0.0000e+00 - val_precision@0.5/anger: 0.0000e+00 - val_recall@0.5/anger: 0.0000e+00 - val_precision@0.5/annoyance: 0.0000e+00 - val_recall@0.5/annoyance: 0.0000e+00 - val_precision@0.5/approval: 0.0000e+00 - val_recall@0.5/approval: 0.0000e+00 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.0000e+00 - val_recall@0.5/curiosity: 0.0000e+00 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.0000e+00 - val_recall@0.5/disapproval: 0.0000e+00 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9810 - val_recall@0.5/gratitude: 0.8149 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.0000e+00 - val_recall@0.5/joy: 0.0000e+00 - val_precision@0.5/love: 1.0000 - val_recall@0.5/love: 0.0448 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.0000e+00 - val_recall@0.5/optimism: 0.0000e+00 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.0000e+00 - val_recall@0.5/remorse: 0.0000e+00 - val_precision@0.5/sadness: 0.0000e+00 - val_recall@0.5/sadness: 0.0000e+00 - val_precision@0.5/surprise: 0.0000e+00  ...
# Epoch 2/10
# 463/463 [==============================] - 563s 1s/step - loss: 0.1486 - precision@0.5/admiration: 0.6801 - recall@0.5/admiration: 0.4311 - precision@0.5/amusement: 0.7723 - recall@0.5/amusement: 0.4466 - precision@0.5/anger: 0.4144 - recall@0.5/anger: 0.0615 - precision@0.5/annoyance: 0.2733 - recall@0.5/annoyance: 0.0352 - precision@0.5/approval: 0.3620 - recall@0.5/approval: 0.0207 - precision@0.5/caring: 0.0000e+00 - recall@0.5/caring: 0.0000e+00 - precision@0.5/confusion: 0.1855 - recall@0.5/confusion: 0.0179 - precision@0.5/curiosity: 0.5914 - recall@0.5/curiosity: 0.3474 - precision@0.5/desire: 0.0000e+00 - recall@0.5/desire: 0.0000e+00 - precision@0.5/disappointment: 0.1667 - recall@0.5/disappointment: 7.7882e-04 - precision@0.5/disapproval: 0.3382 - recall@0.5/disapproval: 0.0234 - precision@0.5/disgust: 0.0000e+00 - recall@0.5/disgust: 0.0000e+00 - precision@0.5/embarrassment: 1.0000 - recall@0.5/embarrassment: 0.0019 - precision@0.5/excitement: 0.0000e+00 - recall@0.5/excitement: 0.0000e+00 - precision@0.5/fear: 0.0000e+00 - recall@0.5/fear: 0.0000e+00 - precision@0.5/gratitude: 0.9082 - recall@0.5/gratitude: 0.7503 - precision@0.5/grief: 0.4167 - recall@0.5/grief: 0.0098 - precision@0.5/joy: 0.4336 - recall@0.5/joy: 0.0349 - precision@0.5/love: 0.7823 - recall@0.5/love: 0.5194 - precision@0.5/nervousness: 1.0000 - recall@0.5/nervousness: 0.0038 - precision@0.5/optimism: 0.5778 - recall@0.5/optimism: 0.0332 - precision@0.5/pride: 1.0000 - recall@0.5/pride: 0.0099 - precision@0.5/realization: 0.0000e+00 - recall@0.5/realization: 0.0000e+00 - precision@0.5/relief: 0.0000e+00 - recall@0.5/relief: 0.0000e+00 - precision@0.5/remorse: 0.5432 - recall@0.5/remorse: 0.0873 - precision@0.5/sadness: 0.5315 - recall@0.5/sadness: 0.0548 - precision@0.5/surprise: 0.5000 - recall@0.5/surprise: 0.0088 - precision@0.5/all: 0.7009 - recall@0.5/all: 0.1892 - f1_score@0.5/all: 0.2348 - f1_score_micro@0.5/all: 0.2980 - f1_score_macro@0.5/all: 0.1373 - val_loss: 0.1108 - val_precision@0.5/admiration: 0.8307 - val_recall@0.5/admiration: 0.4705 - val_precision@0.5/amusement: 0.7925 - val_recall@0.5/amusement: 0.8386 - val_precision@0.5/anger: 0.6610 - val_recall@0.5/anger: 0.3023 - val_precision@0.5/annoyance: 0.0000e+00 - val_recall@0.5/annoyance: 0.0000e+00 - val_precision@0.5/approval: 0.8684 - val_recall@0.5/approval: 0.0682 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.6467 - val_recall@0.5/curiosity: 0.6723 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.7143 - val_recall@0.5/disapproval: 0.0149 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9484 - val_recall@0.5/gratitude: 0.8713 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.6522 - val_recall@0.5/joy: 0.1282 - val_precision@0.5/love: 0.8000 - val_recall@0.5/love: 0.7761 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.7748 - val_recall@0.5/optimism: 0.3346 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.7000 - val_recall@0.5/remorse: 0.5833 - val_precision@0.5/sadness: 0.8800 - val_recall@0.5/sadness: 0.1053 - val_precision@0.5/surprise: 0.6923 - val_recall@0.5 ...
# Epoch 3/10
# 463/463 [==============================] - 609s 1s/step - loss: 0.1248 - precision@0.5/admiration: 0.7472 - recall@0.5/admiration: 0.5563 - precision@0.5/amusement: 0.7993 - recall@0.5/amusement: 0.7118 - precision@0.5/anger: 0.5444 - recall@0.5/anger: 0.2578 - precision@0.5/annoyance: 0.3926 - recall@0.5/annoyance: 0.0923 - precision@0.5/approval: 0.5415 - recall@0.5/approval: 0.0734 - precision@0.5/caring: 0.2791 - recall@0.5/caring: 0.0111 - precision@0.5/confusion: 0.3577 - recall@0.5/confusion: 0.0685 - precision@0.5/curiosity: 0.6272 - recall@0.5/curiosity: 0.4686 - precision@0.5/desire: 1.0000 - recall@0.5/desire: 0.0059 - precision@0.5/disappointment: 0.2000 - recall@0.5/disappointment: 0.0055 - precision@0.5/disapproval: 0.5079 - recall@0.5/disapproval: 0.1146 - precision@0.5/disgust: 0.8182 - recall@0.5/disgust: 0.0180 - precision@0.5/embarrassment: 0.7931 - recall@0.5/embarrassment: 0.0448 - precision@0.5/excitement: 0.0000e+00 - recall@0.5/excitement: 0.0000e+00 - precision@0.5/fear: 0.6304 - recall@0.5/fear: 0.0569 - precision@0.5/gratitude: 0.9141 - recall@0.5/gratitude: 0.8155 - precision@0.5/grief: 0.5510 - recall@0.5/grief: 0.1061 - precision@0.5/joy: 0.5938 - recall@0.5/joy: 0.1916 - precision@0.5/love: 0.7911 - recall@0.5/love: 0.6752 - precision@0.5/nervousness: 0.7750 - recall@0.5/nervousness: 0.0585 - precision@0.5/optimism: 0.7038 - recall@0.5/optimism: 0.2258 - precision@0.5/pride: 0.8211 - recall@0.5/pride: 0.1542 - precision@0.5/realization: 0.5000 - recall@0.5/realization: 0.0018 - precision@0.5/relief: 0.2778 - recall@0.5/relief: 0.0100 - precision@0.5/remorse: 0.6017 - recall@0.5/remorse: 0.2817 - precision@0.5/sadness: 0.5687 - recall@0.5/sadness: 0.2118 - precision@0.5/surprise: 0.6141 - recall@0.5/surprise: 0.1440 - precision@0.5/all: 0.7103 - recall@0.5/all: 0.2940 - f1_score@0.5/all: 0.3542 - f1_score_micro@0.5/all: 0.4158 - f1_score_macro@0.5/all: 0.2534 - val_loss: 0.1042 - val_precision@0.5/admiration: 0.7676 - val_recall@0.5/admiration: 0.5944 - val_precision@0.5/amusement: 0.8025 - val_recall@0.5/amusement: 0.8492 - val_precision@0.5/anger: 0.5583 - val_recall@0.5/anger: 0.4457 - val_precision@0.5/annoyance: 0.4265 - val_recall@0.5/annoyance: 0.1422 - val_precision@0.5/approval: 0.5878 - val_recall@0.5/approval: 0.1798 - val_precision@0.5/caring: 0.8571 - val_recall@0.5/caring: 0.0333 - val_precision@0.5/confusion: 1.0000 - val_recall@0.5/confusion: 0.0183 - val_precision@0.5/curiosity: 0.6277 - val_recall@0.5/curiosity: 0.6667 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.5133 - val_recall@0.5/disapproval: 0.3452 - val_precision@0.5/disgust: 1.0000 - val_recall@0.5/disgust: 0.0224 - val_precision@0.5/embarrassment: 0.6087 - val_recall@0.5/embarrassment: 0.3043 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.7500 - val_recall@0.5/fear: 0.2121 - val_precision@0.5/gratitude: 0.9461 - val_recall@0.5/gratitude: 0.8713 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.6972 - val_recall@0.5/joy: 0.3248 - val_precision@0.5/love: 0.7859 - val_recall@0.5/love: 0.8328 - val_precision@0.5/nervousness: 0.6923 - val_recall@0.5/nervousness: 0.3750 - val_precision@0.5/optimism: 0.7533 - val_recall@0.5/optimism: 0.4397 - val_precision@0.5/pride: 0.5714 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6632 - val_recall@0.5/remorse: 0.7500 - val_precision@0.5/sadness: 0.7975 - val_recall@0.5/sadness: 0.3014 - val_precision@0.5/surprise: 0.6509 - val_recall@0.5/surprise: 0.4012 - val_precision@0.5/all: 0.7181 - val_recall@0.5/all: 0.4075 - val_f1_score@0.5/all: 0.4550 - val_ ...
# Epoch 4/10
# 463/463 [==============================] - 627s 1s/step - loss: 0.1116 - precision@0.5/admiration: 0.7843 - recall@0.5/admiration: 0.6110 - precision@0.5/amusement: 0.8114 - recall@0.5/amusement: 0.7262 - precision@0.5/anger: 0.5563 - recall@0.5/anger: 0.3233 - precision@0.5/annoyance: 0.4107 - recall@0.5/annoyance: 0.1237 - precision@0.5/approval: 0.6260 - recall@0.5/approval: 0.1440 - precision@0.5/caring: 0.4672 - recall@0.5/caring: 0.0526 - precision@0.5/confusion: 0.4075 - recall@0.5/confusion: 0.0927 - precision@0.5/curiosity: 0.6610 - recall@0.5/curiosity: 0.5152 - precision@0.5/desire: 0.7647 - recall@0.5/desire: 0.0766 - precision@0.5/disappointment: 0.5056 - recall@0.5/disappointment: 0.0350 - precision@0.5/disapproval: 0.5393 - recall@0.5/disapproval: 0.1747 - precision@0.5/disgust: 0.6275 - recall@0.5/disgust: 0.0640 - precision@0.5/embarrassment: 0.7119 - recall@0.5/embarrassment: 0.1637 - precision@0.5/excitement: 0.5000 - recall@0.5/excitement: 0.0080 - precision@0.5/fear: 0.7107 - recall@0.5/fear: 0.2216 - precision@0.5/gratitude: 0.9313 - recall@0.5/gratitude: 0.8376 - precision@0.5/grief: 0.7423 - recall@0.5/grief: 0.2829 - precision@0.5/joy: 0.6217 - recall@0.5/joy: 0.2856 - precision@0.5/love: 0.8150 - recall@0.5/love: 0.7201 - precision@0.5/nervousness: 0.7208 - recall@0.5/nervousness: 0.2094 - precision@0.5/optimism: 0.7385 - recall@0.5/optimism: 0.3476 - precision@0.5/pride: 0.9055 - recall@0.5/pride: 0.3597 - precision@0.5/realization: 0.4000 - recall@0.5/realization: 0.0055 - precision@0.5/relief: 0.4103 - recall@0.5/relief: 0.0319 - precision@0.5/remorse: 0.6000 - recall@0.5/remorse: 0.3452 - precision@0.5/sadness: 0.6271 - recall@0.5/sadness: 0.3199 - precision@0.5/surprise: 0.6486 - recall@0.5/surprise: 0.3035 - precision@0.5/all: 0.7252 - recall@0.5/all: 0.3556 - f1_score@0.5/all: 0.4277 - f1_score_micro@0.5/all: 0.4772 - f1_score_macro@0.5/all: 0.3489 - val_loss: 0.1023 - val_precision@0.5/admiration: 0.7628 - val_recall@0.5/admiration: 0.5929 - val_precision@0.5/amusement: 0.7809 - val_recall@0.5/amusement: 0.8862 - val_precision@0.5/anger: 0.5357 - val_recall@0.5/anger: 0.5233 - val_precision@0.5/annoyance: 0.4155 - val_recall@0.5/annoyance: 0.2892 - val_precision@0.5/approval: 0.5256 - val_recall@0.5/approval: 0.2541 - val_precision@0.5/caring: 0.5410 - val_recall@0.5/caring: 0.1833 - val_precision@0.5/confusion: 0.8235 - val_recall@0.5/confusion: 0.1284 - val_precision@0.5/curiosity: 0.6197 - val_recall@0.5/curiosity: 0.6582 - val_precision@0.5/desire: 0.6957 - val_recall@0.5/desire: 0.3168 - val_precision@0.5/disappointment: 0.4167 - val_recall@0.5/disappointment: 0.0243 - val_precision@0.5/disapproval: 0.5082 - val_recall@0.5/disapproval: 0.2768 - val_precision@0.5/disgust: 0.5429 - val_recall@0.5/disgust: 0.1418 - val_precision@0.5/embarrassment: 0.6562 - val_recall@0.5/embarrassment: 0.4565 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.7119 - val_recall@0.5/fear: 0.4242 - val_precision@0.5/gratitude: 0.9396 - val_recall@0.5/gratitude: 0.8781 - val_precision@0.5/grief: 0.1538 - val_recall@0.5/grief: 0.2222 - val_precision@0.5/joy: 0.7281 - val_recall@0.5/joy: 0.3547 - val_precision@0.5/love: 0.7896 - val_recall@0.5/love: 0.8179 - val_precision@0.5/nervousness: 0.4615 - val_recall@0.5/nervousness: 0.5000 - val_precision@0.5/optimism: 0.6910 - val_recall@0.5/optimism: 0.4786 - val_precision@0.5/pride: 0.4545 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6707 - val_recall@0.5/remorse: 0.6548 - val_precision@0.5/sadness: 0.7073 - val_recall@0.5/sadness: 0.4163 - val_precision@0.5/surprise: 0.6341 - val_recall@0.5/surprise: 0.4535 - val_precision@0.5/all: 0.6826 - val_recall@0.5/all: 0.4543 - val_f1_score@0.5/all: 0.5025 - val_f1_score_micro@0.5/all: 0.5455 - ...
# Epoch 5/10
# 463/463 [==============================] - 626s 1s/step - loss: 0.1014 - precision@0.5/admiration: 0.8042 - recall@0.5/admiration: 0.6579 - precision@0.5/amusement: 0.8378 - recall@0.5/amusement: 0.7738 - precision@0.5/anger: 0.6032 - recall@0.5/anger: 0.3808 - precision@0.5/annoyance: 0.4518 - recall@0.5/annoyance: 0.1609 - precision@0.5/approval: 0.6821 - recall@0.5/approval: 0.2427 - precision@0.5/caring: 0.6265 - recall@0.5/caring: 0.1485 - precision@0.5/confusion: 0.4487 - recall@0.5/confusion: 0.1363 - precision@0.5/curiosity: 0.6822 - recall@0.5/curiosity: 0.5480 - precision@0.5/desire: 0.7724 - recall@0.5/desire: 0.1866 - precision@0.5/disappointment: 0.6071 - recall@0.5/disappointment: 0.0662 - precision@0.5/disapproval: 0.6176 - recall@0.5/disapproval: 0.2649 - precision@0.5/disgust: 0.6238 - recall@0.5/disgust: 0.1260 - precision@0.5/embarrassment: 0.8602 - recall@0.5/embarrassment: 0.3119 - precision@0.5/excitement: 0.3529 - recall@0.5/excitement: 0.0120 - precision@0.5/fear: 0.7992 - recall@0.5/fear: 0.3902 - precision@0.5/gratitude: 0.9344 - recall@0.5/gratitude: 0.8471 - precision@0.5/grief: 0.8419 - recall@0.5/grief: 0.5128 - precision@0.5/joy: 0.6639 - recall@0.5/joy: 0.3476 - precision@0.5/love: 0.8186 - recall@0.5/love: 0.7421 - precision@0.5/nervousness: 0.7850 - recall@0.5/nervousness: 0.4340 - precision@0.5/optimism: 0.7494 - recall@0.5/optimism: 0.4024 - precision@0.5/pride: 0.8763 - recall@0.5/pride: 0.5040 - precision@0.5/realization: 0.6047 - recall@0.5/realization: 0.0239 - precision@0.5/relief: 0.6143 - recall@0.5/relief: 0.0857 - precision@0.5/remorse: 0.6697 - recall@0.5/remorse: 0.4425 - precision@0.5/sadness: 0.6751 - recall@0.5/sadness: 0.3847 - precision@0.5/surprise: 0.6956 - recall@0.5/surprise: 0.3823 - precision@0.5/all: 0.7476 - recall@0.5/all: 0.4170 - f1_score@0.5/all: 0.4958 - f1_score_micro@0.5/all: 0.5354 - f1_score_macro@0.5/all: 0.4389 - val_loss: 0.1020 - val_precision@0.5/admiration: 0.7509 - val_recall@0.5/admiration: 0.5959 - val_precision@0.5/amusement: 0.7880 - val_recall@0.5/amusement: 0.8651 - val_precision@0.5/anger: 0.5455 - val_recall@0.5/anger: 0.4884 - val_precision@0.5/annoyance: 0.4071 - val_recall@0.5/annoyance: 0.3113 - val_precision@0.5/approval: 0.4667 - val_recall@0.5/approval: 0.2748 - val_precision@0.5/caring: 0.4494 - val_recall@0.5/caring: 0.2222 - val_precision@0.5/confusion: 0.7234 - val_recall@0.5/confusion: 0.1560 - val_precision@0.5/curiosity: 0.6223 - val_recall@0.5/curiosity: 0.6469 - val_precision@0.5/desire: 0.6809 - val_recall@0.5/desire: 0.3168 - val_precision@0.5/disappointment: 0.4516 - val_recall@0.5/disappointment: 0.0680 - val_precision@0.5/disapproval: 0.5095 - val_recall@0.5/disapproval: 0.3185 - val_precision@0.5/disgust: 0.5962 - val_recall@0.5/disgust: 0.2313 - val_precision@0.5/embarrassment: 0.6774 - val_recall@0.5/embarrassment: 0.4565 - val_precision@0.5/excitement: 1.0000 - val_recall@0.5/excitement: 0.0368 - val_precision@0.5/fear: 0.6790 - val_recall@0.5/fear: 0.5556 - val_precision@0.5/gratitude: 0.9403 - val_recall@0.5/gratitude: 0.8894 - val_precision@0.5/grief: 0.2857 - val_recall@0.5/grief: 0.4444 - val_precision@0.5/joy: 0.6855 - val_recall@0.5/joy: 0.3632 - val_precision@0.5/love: 0.7747 - val_recall@0.5/love: 0.8418 - val_precision@0.5/nervousness: 0.5238 - val_recall@0.5/nervousness: 0.4583 - val_precision@0.5/optimism: 0.6889 - val_recall@0.5/optimism: 0.4825 - val_precision@0.5/pride: 0.4444 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.7500 - val_recall@0.5/realization: 0.0333 - val_precision@0.5/relief: 0.4444 - val_recall@0.5/relief: 0.1739 - val_precision@0.5/remorse: 0.6742 - val_recall@0.5/remorse: 0.7143 - val_precision@0.5/sadness: 0.6911 - val_recall@0.5/sadness: 0.4067 - val_precision@0.5/surprise: 0.6260 - val_recall@0.5/surprise: 0.4767 - val_precision@0.5/all: 0.6676 - val_recall@0.5/all: 0.4708 - val_f1_score@0.5/all: 0.5178 - val_f1_score_micro@0.5/all: 0.5522 - val_f1_score_macro@0.5/ ...
# Epoch 6/10
# 463/463 [==============================] - 618s 1s/step - loss: 0.0933 - precision@0.5/admiration: 0.8268 - recall@0.5/admiration: 0.6985 - precision@0.5/amusement: 0.8361 - recall@0.5/amusement: 0.7851 - precision@0.5/anger: 0.6663 - recall@0.5/anger: 0.4589 - precision@0.5/annoyance: 0.5141 - recall@0.5/annoyance: 0.2259 - precision@0.5/approval: 0.7278 - recall@0.5/approval: 0.3165 - precision@0.5/caring: 0.6331 - recall@0.5/caring: 0.2085 - precision@0.5/confusion: 0.5114 - recall@0.5/confusion: 0.1745 - precision@0.5/curiosity: 0.7266 - recall@0.5/curiosity: 0.5989 - precision@0.5/desire: 0.7184 - recall@0.5/desire: 0.2456 - precision@0.5/disappointment: 0.6079 - recall@0.5/disappointment: 0.1075 - precision@0.5/disapproval: 0.6415 - recall@0.5/disapproval: 0.3209 - precision@0.5/disgust: 0.6765 - recall@0.5/disgust: 0.1840 - precision@0.5/embarrassment: 0.8235 - recall@0.5/embarrassment: 0.3821 - precision@0.5/excitement: 0.6122 - recall@0.5/excitement: 0.0600 - precision@0.5/fear: 0.7906 - recall@0.5/fear: 0.4961 - precision@0.5/gratitude: 0.9392 - recall@0.5/gratitude: 0.8544 - precision@0.5/grief: 0.8679 - recall@0.5/grief: 0.6582 - precision@0.5/joy: 0.6812 - recall@0.5/joy: 0.3775 - precision@0.5/love: 0.8264 - recall@0.5/love: 0.7538 - precision@0.5/nervousness: 0.8419 - recall@0.5/nervousness: 0.5226 - precision@0.5/optimism: 0.7528 - recall@0.5/optimism: 0.4254 - precision@0.5/pride: 0.9138 - recall@0.5/pride: 0.5870 - precision@0.5/realization: 0.6625 - recall@0.5/realization: 0.0488 - precision@0.5/relief: 0.6797 - recall@0.5/relief: 0.1733 - precision@0.5/remorse: 0.6760 - recall@0.5/remorse: 0.4802 - precision@0.5/sadness: 0.7073 - recall@0.5/sadness: 0.4388 - precision@0.5/surprise: 0.7068 - recall@0.5/surprise: 0.4173 - precision@0.5/all: 0.7641 - recall@0.5/all: 0.4636 - f1_score@0.5/all: 0.5446 - f1_score_micro@0.5/all: 0.5770 - f1_score_macro@0.5/all: 0.4970 - val_loss: 0.1032 - val_precision@0.5/admiration: 0.7632 - val_recall@0.5/admiration: 0.5988 - val_precision@0.5/amusement: 0.7917 - val_recall@0.5/amusement: 0.8545 - val_precision@0.5/anger: 0.5192 - val_recall@0.5/anger: 0.5233 - val_precision@0.5/annoyance: 0.3864 - val_recall@0.5/annoyance: 0.3627 - val_precision@0.5/approval: 0.4365 - val_recall@0.5/approval: 0.2913 - val_precision@0.5/caring: 0.4536 - val_recall@0.5/caring: 0.2444 - val_precision@0.5/confusion: 0.6167 - val_recall@0.5/confusion: 0.1697 - val_precision@0.5/curiosity: 0.6224 - val_recall@0.5/curiosity: 0.6751 - val_precision@0.5/desire: 0.7059 - val_recall@0.5/desire: 0.3564 - val_precision@0.5/disappointment: 0.3714 - val_recall@0.5/disappointment: 0.0631 - val_precision@0.5/disapproval: 0.4837 - val_recall@0.5/disapproval: 0.3542 - val_precision@0.5/disgust: 0.5517 - val_recall@0.5/disgust: 0.2388 - val_precision@0.5/embarrassment: 0.6667 - val_recall@0.5/embarrassment: 0.4348 - val_precision@0.5/excitement: 1.0000 - val_recall@0.5/excitement: 0.0809 - val_precision@0.5/fear: 0.6800 - val_recall@0.5/fear: 0.5152 - val_precision@0.5/gratitude: 0.9233 - val_recall@0.5/gratitude: 0.8962 - val_precision@0.5/grief: 0.2857 - val_recall@0.5/grief: 0.4444 - val_precision@0.5/joy: 0.6752 - val_recall@0.5/joy: 0.3376 - val_precision@0.5/love: 0.7678 - val_recall@0.5/love: 0.8388 - val_precision@0.5/nervousness: 0.4762 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.6335 - val_recall@0.5/optimism: 0.5447 - val_precision@0.5/pride: 0.3846 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.6316 - val_recall@0.5/realization: 0.0667 - val_precision@0.5/relief: 0.4000 - val_recall@0.5/relief: 0.1739 - val_precision@0.5/remorse: 0.6444 - val_recall@0.5/remorse: 0.6905 - val_precision@0.5/sadness: 0.6667 - val_recall@0.5/sadness: 0.3732 - val_precision@0.5/surprise: 0.6457 - val_recall@0.5/surprise: 0.4767 - val_precision@0.5/all: 0.6458 - val_recall@0.5/all: 0.4839 - val_f1_score@0.5/all: 0.5240 - val_f1_score_micro@0.5/all: 0.5533 - val_f1_score_macro@0.5/ ...
# Epoch 7/10
# 463/463 [==============================] - 619s 1s/step - loss: 0.0867 - precision@0.5/admiration: 0.8411 - recall@0.5/admiration: 0.7089 - precision@0.5/amusement: 0.8619 - recall@0.5/amusement: 0.7991 - precision@0.5/anger: 0.6742 - recall@0.5/anger: 0.4770 - precision@0.5/annoyance: 0.5427 - recall@0.5/annoyance: 0.2553 - precision@0.5/approval: 0.7521 - recall@0.5/approval: 0.3836 - precision@0.5/caring: 0.7019 - recall@0.5/caring: 0.3063 - precision@0.5/confusion: 0.5385 - recall@0.5/confusion: 0.2072 - precision@0.5/curiosity: 0.7366 - recall@0.5/curiosity: 0.6193 - precision@0.5/desire: 0.7820 - recall@0.5/desire: 0.3242 - precision@0.5/disappointment: 0.6042 - recall@0.5/disappointment: 0.1332 - precision@0.5/disapproval: 0.6789 - recall@0.5/disapproval: 0.3943 - precision@0.5/disgust: 0.6600 - recall@0.5/disgust: 0.2640 - precision@0.5/embarrassment: 0.8430 - recall@0.5/embarrassment: 0.4815 - precision@0.5/excitement: 0.7015 - recall@0.5/excitement: 0.0940 - precision@0.5/fear: 0.8164 - recall@0.5/fear: 0.5667 - precision@0.5/gratitude: 0.9427 - recall@0.5/gratitude: 0.8723 - precision@0.5/grief: 0.8629 - recall@0.5/grief: 0.7171 - precision@0.5/joy: 0.7150 - recall@0.5/joy: 0.4252 - precision@0.5/love: 0.8463 - recall@0.5/love: 0.7875 - precision@0.5/nervousness: 0.8524 - recall@0.5/nervousness: 0.6321 - precision@0.5/optimism: 0.7500 - recall@0.5/optimism: 0.4688 - precision@0.5/pride: 0.9196 - recall@0.5/pride: 0.6779 - precision@0.5/realization: 0.6753 - recall@0.5/realization: 0.0958 - precision@0.5/relief: 0.7539 - recall@0.5/relief: 0.2869 - precision@0.5/remorse: 0.6997 - recall@0.5/remorse: 0.5040 - precision@0.5/sadness: 0.7305 - recall@0.5/sadness: 0.4726 - precision@0.5/surprise: 0.7594 - recall@0.5/surprise: 0.5126 - precision@0.5/all: 0.7797 - recall@0.5/all: 0.5060 - f1_score@0.5/all: 0.5872 - f1_score_micro@0.5/all: 0.6137 - f1_score_macro@0.5/all: 0.5514 - val_loss: 0.1047 - val_precision@0.5/admiration: 0.7434 - val_recall@0.5/admiration: 0.6195 - val_precision@0.5/amusement: 0.7888 - val_recall@0.5/amusement: 0.8598 - val_precision@0.5/anger: 0.5116 - val_recall@0.5/anger: 0.5116 - val_precision@0.5/annoyance: 0.3904 - val_recall@0.5/annoyance: 0.3578 - val_precision@0.5/approval: 0.4124 - val_recall@0.5/approval: 0.3017 - val_precision@0.5/caring: 0.4490 - val_recall@0.5/caring: 0.2444 - val_precision@0.5/confusion: 0.4944 - val_recall@0.5/confusion: 0.2018 - val_precision@0.5/curiosity: 0.6361 - val_recall@0.5/curiosity: 0.6667 - val_precision@0.5/desire: 0.6939 - val_recall@0.5/desire: 0.3366 - val_precision@0.5/disappointment: 0.3077 - val_recall@0.5/disappointment: 0.0777 - val_precision@0.5/disapproval: 0.4758 - val_recall@0.5/disapproval: 0.3810 - val_precision@0.5/disgust: 0.5781 - val_recall@0.5/disgust: 0.2761 - val_precision@0.5/embarrassment: 0.6452 - val_recall@0.5/embarrassment: 0.4348 - val_precision@0.5/excitement: 0.6875 - val_recall@0.5/excitement: 0.0809 - val_precision@0.5/fear: 0.6892 - val_recall@0.5/fear: 0.5152 - val_precision@0.5/gratitude: 0.9296 - val_recall@0.5/gratitude: 0.8939 - val_precision@0.5/grief: 0.2727 - val_recall@0.5/grief: 0.3333 - val_precision@0.5/joy: 0.6577 - val_recall@0.5/joy: 0.4188 - val_precision@0.5/love: 0.7727 - val_recall@0.5/love: 0.8627 - val_precision@0.5/nervousness: 0.4737 - val_recall@0.5/nervousness: 0.3750 - val_precision@0.5/optimism: 0.5923 - val_recall@0.5/optimism: 0.5370 - val_precision@0.5/pride: 0.3077 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.5000 - val_recall@0.5/realization: 0.0778 - val_precision@0.5/relief: 0.4286 - val_recall@0.5/relief: 0.2609 - val_precision@0.5/remorse: 0.6588 - val_recall@0.5/remorse: 0.6667 - val_precision@0.5/sadness: 0.6320 - val_recall@0.5/sadness: 0.3780 - val_precision@0.5/surprise: 0.6269 - val_recall@0.5/surprise: 0.4884 - val_precision@0.5/all: 0.6328 - val_recall@0.5/all: 0.4941 - val_f1_score@0.5/all: 0.5292 - val_f1_score_micro@0.5/all: 0.5549 - val_f1_score_macro@0.5/ ...

# %%
eval_metrics = model.evaluate(x=test_ds, return_dict=True)
utils.print_metrics(eval_metrics)
# Out:
# 73/73 [==============================] - 23s 318ms/step - loss: 0.0897 - precision@0.5/admiration: 0.6796 - recall@0.5/admiration: 0.7042 - precision@0.5/amusement: 0.7639 - recall@0.5/amusement: 0.8648 - precision@0.5/anger: 0.4954 - recall@0.5/anger: 0.5373 - precision@0.5/annoyance: 0.3242 - recall@0.5/annoyance: 0.3581 - precision@0.5/approval: 0.4538 - recall@0.5/approval: 0.4015 - precision@0.5/caring: 0.5140 - recall@0.5/caring: 0.4074 - precision@0.5/confusion: 0.4432 - recall@0.5/confusion: 0.2241 - precision@0.5/curiosity: 0.5561 - recall@0.5/curiosity: 0.7402 - precision@0.5/desire: 0.6889 - recall@0.5/desire: 0.3924 - precision@0.5/disappointment: 0.3256 - recall@0.5/disappointment: 0.0972 - precision@0.5/disapproval: 0.4609 - recall@0.5/disapproval: 0.3849 - precision@0.5/disgust: 0.6271 - recall@0.5/disgust: 0.3737 - precision@0.5/embarrassment: 0.7917 - recall@0.5/embarrassment: 0.4872 - precision@0.5/excitement: 0.8235 - recall@0.5/excitement: 0.1443 - precision@0.5/fear: 0.7667 - recall@0.5/fear: 0.5287 - precision@0.5/gratitude: 0.9109 - recall@0.5/gratitude: 0.9109 - precision@0.5/grief: 0.4444 - recall@0.5/grief: 0.5000 - precision@0.5/joy: 0.6288 - recall@0.5/joy: 0.5030 - precision@0.5/love: 0.7325 - recall@0.5/love: 0.8926 - precision@0.5/nervousness: 0.3846 - recall@0.5/nervousness: 0.2941 - precision@0.5/optimism: 0.5368 - recall@0.5/optimism: 0.5965 - precision@0.5/pride: 0.4000 - recall@0.5/pride: 0.7273 - precision@0.5/realization: 0.6667 - recall@0.5/realization: 0.1905 - precision@0.5/relief: 0.2353 - recall@0.5/relief: 0.2353 - precision@0.5/remorse: 0.6585 - recall@0.5/remorse: 0.8182 - precision@0.5/sadness: 0.5920 - recall@0.5/sadness: 0.4654 - precision@0.5/surprise: 0.6000 - recall@0.5/surprise: 0.5106 - precision@0.5/all: 0.6038 - recall@0.5/all: 0.5547 - f1_score@0.5/all: 0.5599 - f1_score_micro@0.5/all: 0.5782 - f1_score_macro@0.5/all: 0.5066
# metric                          value
# ----------------------------  -------
# loss                          0.08974
# precision@0.5/admiration      0.67956
# recall@0.5/admiration         0.70420
# precision@0.5/amusement       0.76389
# recall@0.5/amusement          0.86478
# precision@0.5/anger           0.49541
# recall@0.5/anger              0.53731
# precision@0.5/annoyance       0.32416
# recall@0.5/annoyance          0.35811
# precision@0.5/approval        0.45376
# recall@0.5/approval           0.40153
# precision@0.5/caring          0.51402
# recall@0.5/caring             0.40741
# precision@0.5/confusion       0.44318
# recall@0.5/confusion          0.22414
# precision@0.5/curiosity       0.55615
# recall@0.5/curiosity          0.74021
# precision@0.5/desire          0.68889
# recall@0.5/desire             0.39241
# precision@0.5/disappointment  0.32558
# recall@0.5/disappointment     0.09722
# precision@0.5/disapproval     0.46091
# recall@0.5/disapproval        0.38488
# precision@0.5/disgust         0.62712
# recall@0.5/disgust            0.37374
# precision@0.5/embarrassment   0.79167
# recall@0.5/embarrassment      0.48718
# precision@0.5/excitement      0.82353
# recall@0.5/excitement         0.14433
# precision@0.5/fear            0.76667
# recall@0.5/fear               0.52874
# precision@0.5/gratitude       0.91086
# recall@0.5/gratitude          0.91086
# precision@0.5/grief           0.44444
# recall@0.5/grief              0.50000
# precision@0.5/joy             0.62879
# recall@0.5/joy                0.50303
# precision@0.5/love            0.73252
# recall@0.5/love               0.89259
# precision@0.5/nervousness     0.38462
# recall@0.5/nervousness        0.29412
# precision@0.5/optimism        0.53684
# recall@0.5/optimism           0.59649
# precision@0.5/pride           0.40000
# recall@0.5/pride              0.72727
# precision@0.5/realization     0.66667
# recall@0.5/realization        0.19048
# precision@0.5/relief          0.23529
# recall@0.5/relief             0.23529
# precision@0.5/remorse         0.65854
# recall@0.5/remorse            0.81818
# precision@0.5/sadness         0.59200
# recall@0.5/sadness            0.46541
# precision@0.5/surprise        0.60000
# recall@0.5/surprise           0.51064
# precision@0.5/all             0.60383
# recall@0.5/all                0.55465
# f1_score@0.5/all              0.55993
# f1_score_micro@0.5/all        0.57819
# f1_score_macro@0.5/all        0.50660

# %%
stats = history.history
stats_plots = {
    'Val Loss': stats['val_loss'],
    'Val Precision All': stats['precision@0.5/all'],
    'Val Recall All': stats['recall@0.5/all'],
    'Val F1-Score Weighted': stats['f1_score@0.5/all'],
    'Val F1-Score Micro': stats['f1_score_micro@0.5/all'],
    'Val F1-Score Macro': stats['f1_score_macro@0.5/all'],
}
utils.plot_history(stats_plots)

# %% [markdown]
# ## Score test and run most-important metrics on emotions prediction

# %%
from tensorflow.keras.metrics import Precision
from tensorflow_addons.metrics import F1Score


test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(), THRESHOLD)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.6038
# F1-Score (micro): 0.5782
# F1-Score (macro): 0.5066

# %% [markdown]
# ## Score test and run most-important metrics on sentiments prediction

# %%
sentiments = utils.load_sentiments(DATASET_DIR)
sentiment_map = utils.map_sentiments(classes, sentiments)
del sentiment_map[27]
test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(),
                           THRESHOLD, sentiment_map)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.8477
# F1-Score (micro): 0.7734
# F1-Score (macro): 0.7342

# %%
utils.test_examples(model, classes)
# Out:
# I am feeling great today!: admiration 👏
# The weather is so good: admiration 👏
# I have performed well at the university:
# The war has started:
# He is desperate in this cruel world:
# I love the feeling when my girlfriend hugs me: love ❤️
# I hate monday mornings: anger 😡
# Merry Christmas! I told Santa you were good this year and asked him to bring you a year full of joy and pleasure : joy 😃
# brilliant! Such a detailed review, it was a pleasure, thank you! Guys, make sure you find time to read :) Aaaaand you can actually choose sth new): admiration 👏 gratitude 🙏
# I have the new pan for pancakes.: approval 👍
# Relax, bro. Take it easy: relief 😅
# WTF? Are they kidding us? I'm gonna argue with the manager!: annoyance 😒
# OMG, yep!!! That is the final answer! Thank you so much!: gratitude 🙏
# I am so glad this is over: joy 😃
# Sorry, I feel bad for having said that: remorse 😔
# Happy birthday, my friend! I wish you a lot of success!: joy 😃
# What a shame! I will never talk to him: embarrassment 😳
# What if she knows? We don't know what to do: confusion 😕 curiosity 🤔
# WOW! I am really into cinema: surprise 😲
# What if I don't pass the exam? I will never get this driving license!: confusion 😕 curiosity 🤔
# I miss my grandad. I am feeling so lonely after her death. I just lost my closest person..: sadness 😞
# Skipping lessons is so miserable for Oxford stundets!:
# Have a rest, my boy. You had a long trip. I will make us tea and bring a cake.: optimism 🤞
# What a man! My son got the highest rate and will study in Cambridge. Our family is so proud of him!: admiration 👏 pride 😌
# Mmmm, delicious. That's totally the best pasta in Italy!: admiration 👏

# %%
utils.plot_conf_mtrx_all(model, test_ds, classes)

# %%
utils.plot_conf_mtrx_per_class(model, test_ds, classes)
# Out:
# 2/2 [==============================] - 1s 201ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 210ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 196ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 225ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 239ms/step
# 2/2 [==============================] - 0s 201ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 201ms/step
# 2/2 [==============================] - 0s 207ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 256ms/step
# 2/2 [==============================] - 1s 190ms/step
# 2/2 [==============================] - 0s 198ms/step
# 2/2 [==============================] - 0s 212ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 200ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 1s 148ms/step

# %%
model.save('./models/bert_0_7_1_no_neutral', include_optimizer=False)
# Out:
# WARNING:absl:Found untraced functions such as restored_function_body, restored_function_body, restored_function_body, restored_function_body, restored_function_body while saving (showing 5 of 64). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/bert_0_7_1_no_neutral\assets
# INFO:tensorflow:Assets written to: ./models/bert_0_7_1_no_neutral\assets
