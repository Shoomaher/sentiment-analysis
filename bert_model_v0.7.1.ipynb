# %%
from sentiment import utils


DATASET_DIR = './goemotions_data/'
classes = utils.load_classes(DATASET_DIR)
classes.remove('neutral')
classes
# Out:
# ['admiration',
#  'amusement',
#  'anger',
#  'annoyance',
#  'approval',
#  'caring',
#  'confusion',
#  'curiosity',
#  'desire',
#  'disappointment',
#  'disapproval',
#  'disgust',
#  'embarrassment',
#  'excitement',
#  'fear',
#  'gratitude',
#  'grief',
#  'joy',
#  'love',
#  'nervousness',
#  'optimism',
#  'pride',
#  'realization',
#  'relief',
#  'remorse',
#  'sadness',
#  'surprise']

# %%
# %%time
train_df, val_df, test_df = utils.make_dataframes(DATASET_DIR,
                                                  fraction=0.85,
                                                  random=1682284394,
                                                  split_by_class=True,
                                                  drop_neutral=True,
                                                  test_only_singles=True,
                                                  oversample_low=True,
                                                  low_threshold=500)
# Out:
# Random seed: 1682284394
# CPU times: total: 984 ms
# Wall time: 975 ms
# D:\sentiment-analysis\sentiment\utils.py:117: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   class_mask = (df['labels'].str.contains(f'(^|,){label}(,|$)',

# %%
# !mkdir plots

# %%
from tensorflow.data import AUTOTUNE

BATCH_SIZE = 64


dataframes = {'Train': train_df, 'Validation': val_df, 'Test': test_df}
for title, df in dataframes.items():
    utils.plot_class_distrh(df, classes, title, savepath=f'./plots/{title}_Class_Distr.png')
train_ds = utils.make_ts_ds(train_df, classes, BATCH_SIZE, AUTOTUNE)
val_ds = utils.make_ts_ds(val_df, classes, BATCH_SIZE, AUTOTUNE)
test_ds = utils.make_ts_ds(test_df, classes, BATCH_SIZE, AUTOTUNE)

# %%
from sentiment import bert_model

BERT_MODEL = 'small_bert/bert_en_uncased_L-2_H-128_A-2'


model = bert_model.BertSentimentModel(BERT_MODEL, dropout_rate=0.4,
                                      dense_units=256, classes=classes)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
from official.nlp import optimization  # to create AdamW optimizer
import tensorflow as tf
from tensorflow.keras.losses import BinaryCrossentropy


THRESHOLD = 0.5
EPOCHS = 10
INIT_LR = 3e-4


steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
print(f'{steps_per_epoch=}')
num_train_steps = steps_per_epoch * EPOCHS
print(f'{num_train_steps=}')
num_warmup_steps = int(0.1*num_train_steps)
print(f'{num_warmup_steps=}')
optimizer = optimization.create_optimizer(init_lr=INIT_LR,
                                          num_train_steps=num_train_steps,
                                          num_warmup_steps=num_warmup_steps,
                                          optimizer_type='adamw')
metrics = utils.create_metrics(classes, THRESHOLD)
loss = BinaryCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
# Out:
# steps_per_epoch=463
# num_train_steps=4630
# num_warmup_steps=463

# %%
from tensorflow.keras.callbacks import EarlyStopping


history = model.fit(x=train_ds, validation_data=val_ds, epochs=EPOCHS,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=2)])
# Out:
# Epoch 1/10
# 463/463 [==============================] - 577s 1s/step - loss: 0.3006 - precision@0.5/admiration: 0.1558 - recall@0.5/admiration: 0.1701 - precision@0.5/amusement: 0.2277 - recall@0.5/amusement: 0.0104 - precision@0.5/anger: 0.0514 - recall@0.5/anger: 0.0427 - precision@0.5/annoyance: 0.0879 - recall@0.5/annoyance: 0.0817 - precision@0.5/approval: 0.1093 - recall@0.5/approval: 0.0379 - precision@0.5/caring: 0.0313 - recall@0.5/caring: 0.0458 - precision@0.5/confusion: 0.0558 - recall@0.5/confusion: 0.0108 - precision@0.5/curiosity: 0.0897 - recall@0.5/curiosity: 0.1200 - precision@0.5/desire: 0.0169 - recall@0.5/desire: 0.1376 - precision@0.5/disappointment: 0.0333 - recall@0.5/disappointment: 0.0303 - precision@0.5/disapproval: 0.0631 - recall@0.5/disapproval: 0.0676 - precision@0.5/disgust: 0.0195 - recall@0.5/disgust: 0.0720 - precision@0.5/embarrassment: 0.0130 - recall@0.5/embarrassment: 0.1081 - precision@0.5/excitement: 0.0230 - recall@0.5/excitement: 0.0960 - precision@0.5/fear: 0.0153 - recall@0.5/fear: 0.0751 - precision@0.5/gratitude: 0.1262 - recall@0.5/gratitude: 0.1909 - precision@0.5/grief: 0.0172 - recall@0.5/grief: 0.0488 - precision@0.5/joy: 0.0496 - recall@0.5/joy: 0.1516 - precision@0.5/love: 0.0652 - recall@0.5/love: 0.1029 - precision@0.5/nervousness: 0.0141 - recall@0.5/nervousness: 0.0128 - precision@0.5/optimism: 0.0533 - recall@0.5/optimism: 0.1174 - precision@0.5/pride: 0.0156 - recall@0.5/pride: 0.0992 - precision@0.5/realization: 0.0365 - recall@0.5/realization: 0.0753 - precision@0.5/relief: 0.0239 - recall@0.5/relief: 0.0553 - precision@0.5/remorse: 0.0221 - recall@0.5/remorse: 0.0572 - precision@0.5/sadness: 0.0425 - recall@0.5/sadness: 0.0747 - precision@0.5/surprise: 0.0388 - recall@0.5/surprise: 0.0303 - precision@0.5/all: 0.0546 - recall@0.5/all: 0.0884 - f1_score@0.5/all: 0.0720 - f1_score_micro@0.5/all: 0.0675 - f1_score_macro@0.5/all: 0.0526 - val_loss: 0.1437 - val_precision@0.5/admiration: 0.9016 - val_recall@0.5/admiration: 0.0811 - val_precision@0.5/amusement: 0.0000e+00 - val_recall@0.5/amusement: 0.0000e+00 - val_precision@0.5/anger: 0.0000e+00 - val_recall@0.5/anger: 0.0000e+00 - val_precision@0.5/annoyance: 0.0000e+00 - val_recall@0.5/annoyance: 0.0000e+00 - val_precision@0.5/approval: 0.0000e+00 - val_recall@0.5/approval: 0.0000e+00 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.7260 - val_recall@0.5/curiosity: 0.1497 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.0000e+00 - val_recall@0.5/disapproval: 0.0000e+00 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9816 - val_recall@0.5/gratitude: 0.8442 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.0000e+00 - val_recall@0.5/joy: 0.0000e+00 - val_precision@0.5/love: 0.0000e+00 - val_recall@0.5/love: 0.0000e+00 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.0000e+00 - val_recall@0.5/optimism: 0.0000e+00 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.0000e+00 - val_recall@0.5/remorse: 0.0000e+00 - val_precision@0.5/sadness: 0.0000e+00 - val_recall@0.5/sadness: 0.0000e+00 - val_precision@0.5/surprise: 0.0000e+00  ...
# Epoch 2/10
# 463/463 [==============================] - 554s 1s/step - loss: 0.1493 - precision@0.5/admiration: 0.6697 - recall@0.5/admiration: 0.4214 - precision@0.5/amusement: 0.7803 - recall@0.5/amusement: 0.5179 - precision@0.5/anger: 0.5143 - recall@0.5/anger: 0.0360 - precision@0.5/annoyance: 0.2945 - recall@0.5/annoyance: 0.0180 - precision@0.5/approval: 0.2742 - recall@0.5/approval: 0.0118 - precision@0.5/caring: 0.6667 - recall@0.5/caring: 0.0018 - precision@0.5/confusion: 0.2679 - recall@0.5/confusion: 0.0231 - precision@0.5/curiosity: 0.6150 - recall@0.5/curiosity: 0.3812 - precision@0.5/desire: 0.5000 - recall@0.5/desire: 0.0097 - precision@0.5/disappointment: 0.0000e+00 - recall@0.5/disappointment: 0.0000e+00 - precision@0.5/disapproval: 0.3150 - recall@0.5/disapproval: 0.0323 - precision@0.5/disgust: 0.6667 - recall@0.5/disgust: 0.0040 - precision@0.5/embarrassment: 0.1250 - recall@0.5/embarrassment: 0.0019 - precision@0.5/excitement: 0.0000e+00 - recall@0.5/excitement: 0.0000e+00 - precision@0.5/fear: 0.0000e+00 - recall@0.5/fear: 0.0000e+00 - precision@0.5/gratitude: 0.9065 - recall@0.5/gratitude: 0.7517 - precision@0.5/grief: 0.5714 - recall@0.5/grief: 0.0078 - precision@0.5/joy: 0.5310 - recall@0.5/joy: 0.0558 - precision@0.5/love: 0.8007 - recall@0.5/love: 0.4559 - precision@0.5/nervousness: 0.4000 - recall@0.5/nervousness: 0.0037 - precision@0.5/optimism: 0.6895 - recall@0.5/optimism: 0.1103 - precision@0.5/pride: 0.8333 - recall@0.5/pride: 0.0099 - precision@0.5/realization: 0.0000e+00 - recall@0.5/realization: 0.0000e+00 - precision@0.5/relief: 0.0000e+00 - recall@0.5/relief: 0.0000e+00 - precision@0.5/remorse: 0.3846 - recall@0.5/remorse: 0.0394 - precision@0.5/sadness: 0.4599 - recall@0.5/sadness: 0.0601 - precision@0.5/surprise: 0.4706 - recall@0.5/surprise: 0.0078 - precision@0.5/all: 0.7133 - recall@0.5/all: 0.1926 - f1_score@0.5/all: 0.2393 - f1_score_micro@0.5/all: 0.3033 - f1_score_macro@0.5/all: 0.1407 - val_loss: 0.1114 - val_precision@0.5/admiration: 0.7802 - val_recall@0.5/admiration: 0.5708 - val_precision@0.5/amusement: 0.7798 - val_recall@0.5/amusement: 0.8995 - val_precision@0.5/anger: 0.6337 - val_recall@0.5/anger: 0.2481 - val_precision@0.5/annoyance: 0.7000 - val_recall@0.5/annoyance: 0.0343 - val_precision@0.5/approval: 0.0000e+00 - val_recall@0.5/approval: 0.0000e+00 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.6069 - val_recall@0.5/curiosity: 0.6977 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 1.0000 - val_recall@0.5/disapproval: 0.0149 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9580 - val_recall@0.5/gratitude: 0.8758 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.6852 - val_recall@0.5/joy: 0.3162 - val_precision@0.5/love: 0.8261 - val_recall@0.5/love: 0.7373 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.8000 - val_recall@0.5/optimism: 0.3580 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.7500 - val_recall@0.5/remorse: 0.2143 - val_precision@0.5/sadness: 0.6066 - val_recall@0.5/sadness: 0.3541 - val_precision@0.5/surprise: 0.8125 - val_recall@0.5/surprise: 0.0756 -  ...
# Epoch 3/10
# 463/463 [==============================] - 553s 1s/step - loss: 0.1252 - precision@0.5/admiration: 0.7270 - recall@0.5/admiration: 0.5500 - precision@0.5/amusement: 0.8080 - recall@0.5/amusement: 0.6960 - precision@0.5/anger: 0.5605 - recall@0.5/anger: 0.1855 - precision@0.5/annoyance: 0.4255 - recall@0.5/annoyance: 0.0658 - precision@0.5/approval: 0.4912 - recall@0.5/approval: 0.0779 - precision@0.5/caring: 0.3559 - recall@0.5/caring: 0.0189 - precision@0.5/confusion: 0.3139 - recall@0.5/confusion: 0.0540 - precision@0.5/curiosity: 0.6388 - recall@0.5/curiosity: 0.4821 - precision@0.5/desire: 0.5882 - recall@0.5/desire: 0.0388 - precision@0.5/disappointment: 0.1111 - recall@0.5/disappointment: 7.7700e-04 - precision@0.5/disapproval: 0.4872 - recall@0.5/disapproval: 0.1265 - precision@0.5/disgust: 0.3571 - recall@0.5/disgust: 0.0100 - precision@0.5/embarrassment: 0.6800 - recall@0.5/embarrassment: 0.0328 - precision@0.5/excitement: 1.0000 - recall@0.5/excitement: 0.0060 - precision@0.5/fear: 0.8235 - recall@0.5/fear: 0.0277 - precision@0.5/gratitude: 0.9237 - recall@0.5/gratitude: 0.8281 - precision@0.5/grief: 0.6486 - recall@0.5/grief: 0.1406 - precision@0.5/joy: 0.5824 - recall@0.5/joy: 0.2255 - precision@0.5/love: 0.8007 - recall@0.5/love: 0.6788 - precision@0.5/nervousness: 0.5238 - recall@0.5/nervousness: 0.0201 - precision@0.5/optimism: 0.7015 - recall@0.5/optimism: 0.2942 - precision@0.5/pride: 0.7745 - recall@0.5/pride: 0.1567 - precision@0.5/realization: 0.3333 - recall@0.5/realization: 9.3023e-04 - precision@0.5/relief: 0.0000e+00 - recall@0.5/relief: 0.0000e+00 - precision@0.5/remorse: 0.5263 - recall@0.5/remorse: 0.1972 - precision@0.5/sadness: 0.6259 - recall@0.5/sadness: 0.2325 - precision@0.5/surprise: 0.6502 - recall@0.5/surprise: 0.1419 - precision@0.5/all: 0.7163 - recall@0.5/all: 0.2934 - f1_score@0.5/all: 0.3531 - f1_score_micro@0.5/all: 0.4163 - f1_score_macro@0.5/all: 0.2497 - val_loss: 0.1038 - val_precision@0.5/admiration: 0.7786 - val_recall@0.5/admiration: 0.6327 - val_precision@0.5/amusement: 0.7786 - val_recall@0.5/amusement: 0.8836 - val_precision@0.5/anger: 0.5622 - val_recall@0.5/anger: 0.4729 - val_precision@0.5/annoyance: 0.4885 - val_recall@0.5/annoyance: 0.1569 - val_precision@0.5/approval: 0.6303 - val_recall@0.5/approval: 0.1550 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.8696 - val_recall@0.5/confusion: 0.0917 - val_precision@0.5/curiosity: 0.6246 - val_recall@0.5/curiosity: 0.6299 - val_precision@0.5/desire: 1.0000 - val_recall@0.5/desire: 0.0297 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.6316 - val_recall@0.5/disapproval: 0.1786 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.7727 - val_recall@0.5/embarrassment: 0.3696 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.9000 - val_recall@0.5/fear: 0.0909 - val_precision@0.5/gratitude: 0.9511 - val_recall@0.5/gratitude: 0.8781 - val_precision@0.5/grief: 0.2308 - val_recall@0.5/grief: 0.3333 - val_precision@0.5/joy: 0.6835 - val_recall@0.5/joy: 0.4060 - val_precision@0.5/love: 0.8129 - val_recall@0.5/love: 0.7910 - val_precision@0.5/nervousness: 1.0000 - val_recall@0.5/nervousness: 0.1250 - val_precision@0.5/optimism: 0.7613 - val_recall@0.5/optimism: 0.4591 - val_precision@0.5/pride: 0.6000 - val_recall@0.5/pride: 0.1765 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6615 - val_recall@0.5/remorse: 0.5119 - val_precision@0.5/sadness: 0.6397 - val_recall@0.5/sadness: 0.4163 - val_precision@0.5/surprise: 0.6496 - val_recall@0.5/surprise: 0.4419 - val_precision@0.5/all: 0.7332 - val_recall@0.5/all: 0.4061 - val_f1_score@0.5/all: 0.454 ...
# Epoch 4/10
# 463/463 [==============================] - 552s 1s/step - loss: 0.1125 - precision@0.5/admiration: 0.7733 - recall@0.5/admiration: 0.6171 - precision@0.5/amusement: 0.8248 - recall@0.5/amusement: 0.7528 - precision@0.5/anger: 0.5977 - recall@0.5/anger: 0.2815 - precision@0.5/annoyance: 0.4593 - recall@0.5/annoyance: 0.1182 - precision@0.5/approval: 0.6244 - recall@0.5/approval: 0.1763 - precision@0.5/caring: 0.4898 - recall@0.5/caring: 0.0646 - precision@0.5/confusion: 0.3755 - recall@0.5/confusion: 0.0779 - precision@0.5/curiosity: 0.6693 - recall@0.5/curiosity: 0.5237 - precision@0.5/desire: 0.7312 - recall@0.5/desire: 0.1318 - precision@0.5/disappointment: 0.4800 - recall@0.5/disappointment: 0.0093 - precision@0.5/disapproval: 0.5312 - recall@0.5/disapproval: 0.2003 - precision@0.5/disgust: 0.6000 - recall@0.5/disgust: 0.0360 - precision@0.5/embarrassment: 0.7607 - recall@0.5/embarrassment: 0.1718 - precision@0.5/excitement: 0.5556 - recall@0.5/excitement: 0.0100 - precision@0.5/fear: 0.7155 - recall@0.5/fear: 0.1640 - precision@0.5/gratitude: 0.9268 - recall@0.5/gratitude: 0.8335 - precision@0.5/grief: 0.7658 - recall@0.5/grief: 0.3320 - precision@0.5/joy: 0.6494 - recall@0.5/joy: 0.2915 - precision@0.5/love: 0.8180 - recall@0.5/love: 0.7206 - precision@0.5/nervousness: 0.7075 - recall@0.5/nervousness: 0.1374 - precision@0.5/optimism: 0.7398 - recall@0.5/optimism: 0.3761 - precision@0.5/pride: 0.8654 - recall@0.5/pride: 0.3571 - precision@0.5/realization: 0.6538 - recall@0.5/realization: 0.0158 - precision@0.5/relief: 0.2500 - recall@0.5/relief: 0.0079 - precision@0.5/remorse: 0.5733 - recall@0.5/remorse: 0.2623 - precision@0.5/sadness: 0.6286 - recall@0.5/sadness: 0.3038 - precision@0.5/surprise: 0.6846 - recall@0.5/surprise: 0.2994 - precision@0.5/all: 0.7340 - recall@0.5/all: 0.3576 - f1_score@0.5/all: 0.4297 - f1_score_micro@0.5/all: 0.4809 - f1_score_macro@0.5/all: 0.3442 - val_loss: 0.1019 - val_precision@0.5/admiration: 0.7750 - val_recall@0.5/admiration: 0.6298 - val_precision@0.5/amusement: 0.7967 - val_recall@0.5/amusement: 0.9021 - val_precision@0.5/anger: 0.5433 - val_recall@0.5/anger: 0.5349 - val_precision@0.5/annoyance: 0.4762 - val_recall@0.5/annoyance: 0.1961 - val_precision@0.5/approval: 0.5463 - val_recall@0.5/approval: 0.2314 - val_precision@0.5/caring: 0.6000 - val_recall@0.5/caring: 0.0833 - val_precision@0.5/confusion: 0.7021 - val_recall@0.5/confusion: 0.1514 - val_precision@0.5/curiosity: 0.6383 - val_recall@0.5/curiosity: 0.6780 - val_precision@0.5/desire: 0.7027 - val_recall@0.5/desire: 0.2574 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.5745 - val_recall@0.5/disapproval: 0.2411 - val_precision@0.5/disgust: 1.0000 - val_recall@0.5/disgust: 0.0821 - val_precision@0.5/embarrassment: 0.6364 - val_recall@0.5/embarrassment: 0.4565 - val_precision@0.5/excitement: 1.0000 - val_recall@0.5/excitement: 0.0074 - val_precision@0.5/fear: 0.7170 - val_recall@0.5/fear: 0.3838 - val_precision@0.5/gratitude: 0.9391 - val_recall@0.5/gratitude: 0.9052 - val_precision@0.5/grief: 0.1765 - val_recall@0.5/grief: 0.3333 - val_precision@0.5/joy: 0.6966 - val_recall@0.5/joy: 0.4316 - val_precision@0.5/love: 0.7627 - val_recall@0.5/love: 0.8537 - val_precision@0.5/nervousness: 0.6471 - val_recall@0.5/nervousness: 0.4583 - val_precision@0.5/optimism: 0.7500 - val_recall@0.5/optimism: 0.5253 - val_precision@0.5/pride: 0.4286 - val_recall@0.5/pride: 0.1765 - val_precision@0.5/realization: 0.5000 - val_recall@0.5/realization: 0.0111 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6849 - val_recall@0.5/remorse: 0.5952 - val_precision@0.5/sadness: 0.6250 - val_recall@0.5/sadness: 0.4545 - val_precision@0.5/surprise: 0.6692 - val_recall@0.5/surprise: 0.5174 - val_precision@0.5/all: 0.7098 - val_recall@0.5/all: 0.4564 - val_f1_score@0.5/all: 0.5016 - val_f1_score_micro@0.5/all: 0.5556 - val_f1_ ...
# Epoch 5/10
# 463/463 [==============================] - 552s 1s/step - loss: 0.1017 - precision@0.5/admiration: 0.7961 - recall@0.5/admiration: 0.6590 - precision@0.5/amusement: 0.8311 - recall@0.5/amusement: 0.7737 - precision@0.5/anger: 0.6323 - recall@0.5/anger: 0.3602 - precision@0.5/annoyance: 0.5166 - recall@0.5/annoyance: 0.1626 - precision@0.5/approval: 0.6364 - recall@0.5/approval: 0.2507 - precision@0.5/caring: 0.6374 - recall@0.5/caring: 0.1499 - precision@0.5/confusion: 0.4683 - recall@0.5/confusion: 0.1196 - precision@0.5/curiosity: 0.7049 - recall@0.5/curiosity: 0.5667 - precision@0.5/desire: 0.7794 - recall@0.5/desire: 0.2054 - precision@0.5/disappointment: 0.4821 - recall@0.5/disappointment: 0.0210 - precision@0.5/disapproval: 0.6099 - recall@0.5/disapproval: 0.2828 - precision@0.5/disgust: 0.6721 - recall@0.5/disgust: 0.0820 - precision@0.5/embarrassment: 0.8191 - recall@0.5/embarrassment: 0.3147 - precision@0.5/excitement: 0.6111 - recall@0.5/excitement: 0.0440 - precision@0.5/fear: 0.7555 - recall@0.5/fear: 0.3419 - precision@0.5/gratitude: 0.9315 - recall@0.5/gratitude: 0.8536 - precision@0.5/grief: 0.8272 - recall@0.5/grief: 0.5234 - precision@0.5/joy: 0.6339 - recall@0.5/joy: 0.3278 - precision@0.5/love: 0.8197 - recall@0.5/love: 0.7474 - precision@0.5/nervousness: 0.8252 - recall@0.5/nervousness: 0.3718 - precision@0.5/optimism: 0.7600 - recall@0.5/optimism: 0.4187 - precision@0.5/pride: 0.8759 - recall@0.5/pride: 0.5040 - precision@0.5/realization: 0.4857 - recall@0.5/realization: 0.0316 - precision@0.5/relief: 0.5714 - recall@0.5/relief: 0.0316 - precision@0.5/remorse: 0.6553 - recall@0.5/remorse: 0.3787 - precision@0.5/sadness: 0.6915 - recall@0.5/sadness: 0.3820 - precision@0.5/surprise: 0.7079 - recall@0.5/surprise: 0.4198 - precision@0.5/all: 0.7514 - recall@0.5/all: 0.4160 - f1_score@0.5/all: 0.4930 - f1_score_micro@0.5/all: 0.5355 - f1_score_macro@0.5/all: 0.4301 - val_loss: 0.1015 - val_precision@0.5/admiration: 0.7550 - val_recall@0.5/admiration: 0.6681 - val_precision@0.5/amusement: 0.7943 - val_recall@0.5/amusement: 0.8783 - val_precision@0.5/anger: 0.5159 - val_recall@0.5/anger: 0.5039 - val_precision@0.5/annoyance: 0.4769 - val_recall@0.5/annoyance: 0.2279 - val_precision@0.5/approval: 0.4745 - val_recall@0.5/approval: 0.2686 - val_precision@0.5/caring: 0.5735 - val_recall@0.5/caring: 0.2167 - val_precision@0.5/confusion: 0.5833 - val_recall@0.5/confusion: 0.1927 - val_precision@0.5/curiosity: 0.6524 - val_recall@0.5/curiosity: 0.6045 - val_precision@0.5/desire: 0.6346 - val_recall@0.5/desire: 0.3267 - val_precision@0.5/disappointment: 0.4706 - val_recall@0.5/disappointment: 0.0388 - val_precision@0.5/disapproval: 0.5149 - val_recall@0.5/disapproval: 0.3095 - val_precision@0.5/disgust: 0.7391 - val_recall@0.5/disgust: 0.1269 - val_precision@0.5/embarrassment: 0.7143 - val_recall@0.5/embarrassment: 0.4348 - val_precision@0.5/excitement: 0.9167 - val_recall@0.5/excitement: 0.0809 - val_precision@0.5/fear: 0.6618 - val_recall@0.5/fear: 0.4545 - val_precision@0.5/gratitude: 0.9302 - val_recall@0.5/gratitude: 0.9029 - val_precision@0.5/grief: 0.2632 - val_recall@0.5/grief: 0.5556 - val_precision@0.5/joy: 0.6606 - val_recall@0.5/joy: 0.4658 - val_precision@0.5/love: 0.7994 - val_recall@0.5/love: 0.8090 - val_precision@0.5/nervousness: 0.4400 - val_recall@0.5/nervousness: 0.4583 - val_precision@0.5/optimism: 0.7016 - val_recall@0.5/optimism: 0.5214 - val_precision@0.5/pride: 0.4545 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.6875 - val_recall@0.5/realization: 0.0611 - val_precision@0.5/relief: 1.0000 - val_recall@0.5/relief: 0.0870 - val_precision@0.5/remorse: 0.7143 - val_recall@0.5/remorse: 0.6548 - val_precision@0.5/sadness: 0.5697 - val_recall@0.5/sadness: 0.4498 - val_precision@0.5/surprise: 0.6376 - val_recall@0.5/surprise: 0.5523 - val_precision@0.5/all: 0.6820 - val_recall@0.5/all: 0.4769 - val_f1_score@0.5/all: 0.5234 - val_f1_score_micro@0.5/all: 0.5613 - val_f1_score_macro@0.5/ ...
# Epoch 6/10
# 463/463 [==============================] - 554s 1s/step - loss: 0.0940 - precision@0.5/admiration: 0.8179 - recall@0.5/admiration: 0.7018 - precision@0.5/amusement: 0.8509 - recall@0.5/amusement: 0.7828 - precision@0.5/anger: 0.6591 - recall@0.5/anger: 0.4063 - precision@0.5/annoyance: 0.5419 - recall@0.5/annoyance: 0.2196 - precision@0.5/approval: 0.7080 - recall@0.5/approval: 0.3279 - precision@0.5/caring: 0.6330 - recall@0.5/caring: 0.1858 - precision@0.5/confusion: 0.5370 - recall@0.5/confusion: 0.1906 - precision@0.5/curiosity: 0.7211 - recall@0.5/curiosity: 0.5997 - precision@0.5/desire: 0.7789 - recall@0.5/desire: 0.2868 - precision@0.5/disappointment: 0.6186 - recall@0.5/disappointment: 0.0466 - precision@0.5/disapproval: 0.6568 - recall@0.5/disapproval: 0.3637 - precision@0.5/disgust: 0.7059 - recall@0.5/disgust: 0.1680 - precision@0.5/embarrassment: 0.8235 - recall@0.5/embarrassment: 0.3784 - precision@0.5/excitement: 0.6364 - recall@0.5/excitement: 0.0700 - precision@0.5/fear: 0.8081 - recall@0.5/fear: 0.4743 - precision@0.5/gratitude: 0.9338 - recall@0.5/gratitude: 0.8635 - precision@0.5/grief: 0.8594 - recall@0.5/grief: 0.6445 - precision@0.5/joy: 0.6458 - recall@0.5/joy: 0.3742 - precision@0.5/love: 0.8510 - recall@0.5/love: 0.7806 - precision@0.5/nervousness: 0.8053 - recall@0.5/nervousness: 0.4469 - precision@0.5/optimism: 0.7532 - recall@0.5/optimism: 0.4490 - precision@0.5/pride: 0.8800 - recall@0.5/pride: 0.6111 - precision@0.5/realization: 0.6508 - recall@0.5/realization: 0.0763 - precision@0.5/relief: 0.6076 - recall@0.5/relief: 0.0949 - precision@0.5/remorse: 0.6786 - recall@0.5/remorse: 0.4122 - precision@0.5/sadness: 0.7245 - recall@0.5/sadness: 0.4462 - precision@0.5/surprise: 0.7406 - recall@0.5/surprise: 0.4609 - precision@0.5/all: 0.7681 - recall@0.5/all: 0.4648 - f1_score@0.5/all: 0.5444 - f1_score_micro@0.5/all: 0.5791 - f1_score_macro@0.5/all: 0.4911 - val_loss: 0.1030 - val_precision@0.5/admiration: 0.7641 - val_recall@0.5/admiration: 0.6401 - val_precision@0.5/amusement: 0.7925 - val_recall@0.5/amusement: 0.8995 - val_precision@0.5/anger: 0.4965 - val_recall@0.5/anger: 0.5426 - val_precision@0.5/annoyance: 0.3962 - val_recall@0.5/annoyance: 0.3088 - val_precision@0.5/approval: 0.4819 - val_recall@0.5/approval: 0.2748 - val_precision@0.5/caring: 0.5342 - val_recall@0.5/caring: 0.2167 - val_precision@0.5/confusion: 0.6049 - val_recall@0.5/confusion: 0.2248 - val_precision@0.5/curiosity: 0.6371 - val_recall@0.5/curiosity: 0.6497 - val_precision@0.5/desire: 0.6538 - val_recall@0.5/desire: 0.3366 - val_precision@0.5/disappointment: 0.5000 - val_recall@0.5/disappointment: 0.0825 - val_precision@0.5/disapproval: 0.5000 - val_recall@0.5/disapproval: 0.3125 - val_precision@0.5/disgust: 0.6667 - val_recall@0.5/disgust: 0.1791 - val_precision@0.5/embarrassment: 0.6571 - val_recall@0.5/embarrassment: 0.5000 - val_precision@0.5/excitement: 0.8462 - val_recall@0.5/excitement: 0.0809 - val_precision@0.5/fear: 0.7018 - val_recall@0.5/fear: 0.4040 - val_precision@0.5/gratitude: 0.9327 - val_recall@0.5/gratitude: 0.9074 - val_precision@0.5/grief: 0.2857 - val_recall@0.5/grief: 0.6667 - val_precision@0.5/joy: 0.6325 - val_recall@0.5/joy: 0.4487 - val_precision@0.5/love: 0.7877 - val_recall@0.5/love: 0.8418 - val_precision@0.5/nervousness: 0.4348 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.6389 - val_recall@0.5/optimism: 0.5370 - val_precision@0.5/pride: 0.4545 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.6842 - val_recall@0.5/realization: 0.0722 - val_precision@0.5/relief: 0.3333 - val_recall@0.5/relief: 0.1739 - val_precision@0.5/remorse: 0.7105 - val_recall@0.5/remorse: 0.6429 - val_precision@0.5/sadness: 0.5804 - val_recall@0.5/sadness: 0.3971 - val_precision@0.5/surprise: 0.6277 - val_recall@0.5/surprise: 0.5000 - val_precision@0.5/all: 0.6609 - val_recall@0.5/all: 0.4886 - val_f1_score@0.5/all: 0.5299 - val_f1_score_micro@0.5/all: 0.5618 - val_f1_score_macro@0.5/ ...
# Epoch 7/10
# 463/463 [==============================] - 552s 1s/step - loss: 0.0867 - precision@0.5/admiration: 0.8418 - recall@0.5/admiration: 0.7274 - precision@0.5/amusement: 0.8578 - recall@0.5/amusement: 0.8083 - precision@0.5/anger: 0.6829 - recall@0.5/anger: 0.4683 - precision@0.5/annoyance: 0.5823 - recall@0.5/annoyance: 0.2699 - precision@0.5/approval: 0.7270 - recall@0.5/approval: 0.3870 - precision@0.5/caring: 0.7039 - recall@0.5/caring: 0.2774 - precision@0.5/confusion: 0.5820 - recall@0.5/confusion: 0.2191 - precision@0.5/curiosity: 0.7604 - recall@0.5/curiosity: 0.6404 - precision@0.5/desire: 0.7713 - recall@0.5/desire: 0.3333 - precision@0.5/disappointment: 0.6380 - recall@0.5/disappointment: 0.0808 - precision@0.5/disapproval: 0.7007 - recall@0.5/disapproval: 0.4365 - precision@0.5/disgust: 0.7801 - recall@0.5/disgust: 0.2200 - precision@0.5/embarrassment: 0.8514 - recall@0.5/embarrassment: 0.4865 - precision@0.5/excitement: 0.7024 - recall@0.5/excitement: 0.1180 - precision@0.5/fear: 0.8113 - recall@0.5/fear: 0.5099 - precision@0.5/gratitude: 0.9385 - recall@0.5/gratitude: 0.8764 - precision@0.5/grief: 0.8776 - recall@0.5/grief: 0.7285 - precision@0.5/joy: 0.6805 - recall@0.5/joy: 0.4293 - precision@0.5/love: 0.8615 - recall@0.5/love: 0.7872 - precision@0.5/nervousness: 0.8333 - recall@0.5/nervousness: 0.5586 - precision@0.5/optimism: 0.7639 - recall@0.5/optimism: 0.4884 - precision@0.5/pride: 0.9013 - recall@0.5/pride: 0.6885 - precision@0.5/realization: 0.6609 - recall@0.5/realization: 0.1070 - precision@0.5/relief: 0.6148 - recall@0.5/relief: 0.1482 - precision@0.5/remorse: 0.7054 - recall@0.5/remorse: 0.4675 - precision@0.5/sadness: 0.7463 - recall@0.5/sadness: 0.4993 - precision@0.5/surprise: 0.7652 - recall@0.5/surprise: 0.5039 - precision@0.5/all: 0.7861 - recall@0.5/all: 0.5091 - f1_score@0.5/all: 0.5889 - f1_score_micro@0.5/all: 0.6180 - f1_score_macro@0.5/all: 0.5437 - val_loss: 0.1048 - val_precision@0.5/admiration: 0.7556 - val_recall@0.5/admiration: 0.6431 - val_precision@0.5/amusement: 0.7791 - val_recall@0.5/amusement: 0.8862 - val_precision@0.5/anger: 0.4983 - val_recall@0.5/anger: 0.5853 - val_precision@0.5/annoyance: 0.3907 - val_recall@0.5/annoyance: 0.3505 - val_precision@0.5/approval: 0.4554 - val_recall@0.5/approval: 0.2851 - val_precision@0.5/caring: 0.4796 - val_recall@0.5/caring: 0.2611 - val_precision@0.5/confusion: 0.5259 - val_recall@0.5/confusion: 0.2798 - val_precision@0.5/curiosity: 0.6311 - val_recall@0.5/curiosity: 0.6186 - val_precision@0.5/desire: 0.6346 - val_recall@0.5/desire: 0.3267 - val_precision@0.5/disappointment: 0.4250 - val_recall@0.5/disappointment: 0.0825 - val_precision@0.5/disapproval: 0.4901 - val_recall@0.5/disapproval: 0.2946 - val_precision@0.5/disgust: 0.6744 - val_recall@0.5/disgust: 0.2164 - val_precision@0.5/embarrassment: 0.5946 - val_recall@0.5/embarrassment: 0.4783 - val_precision@0.5/excitement: 0.7778 - val_recall@0.5/excitement: 0.1029 - val_precision@0.5/fear: 0.7077 - val_recall@0.5/fear: 0.4646 - val_precision@0.5/gratitude: 0.9296 - val_recall@0.5/gratitude: 0.8939 - val_precision@0.5/grief: 0.2857 - val_recall@0.5/grief: 0.6667 - val_precision@0.5/joy: 0.6405 - val_recall@0.5/joy: 0.4188 - val_precision@0.5/love: 0.7690 - val_recall@0.5/love: 0.8448 - val_precision@0.5/nervousness: 0.3846 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.6682 - val_recall@0.5/optimism: 0.5486 - val_precision@0.5/pride: 0.4444 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.6818 - val_recall@0.5/realization: 0.0833 - val_precision@0.5/relief: 0.3571 - val_recall@0.5/relief: 0.2174 - val_precision@0.5/remorse: 0.7143 - val_recall@0.5/remorse: 0.6548 - val_precision@0.5/sadness: 0.5789 - val_recall@0.5/sadness: 0.4211 - val_precision@0.5/surprise: 0.6276 - val_recall@0.5/surprise: 0.5291 - val_precision@0.5/all: 0.6453 - val_recall@0.5/all: 0.4968 - val_f1_score@0.5/all: 0.5341 - val_f1_score_micro@0.5/all: 0.5614 - val_f1_score_macro@0.5/ ...

# %%
eval_metrics = model.evaluate(x=test_ds, return_dict=True)
utils.print_metrics(eval_metrics)
# Out:
# 73/73 [==============================] - 22s 298ms/step - loss: 0.0894 - precision@0.5/admiration: 0.6887 - recall@0.5/admiration: 0.7347 - precision@0.5/amusement: 0.7657 - recall@0.5/amusement: 0.8836 - precision@0.5/anger: 0.4730 - recall@0.5/anger: 0.5224 - precision@0.5/annoyance: 0.3117 - recall@0.5/annoyance: 0.3243 - precision@0.5/approval: 0.4984 - recall@0.5/approval: 0.3939 - precision@0.5/caring: 0.5135 - recall@0.5/caring: 0.4222 - precision@0.5/confusion: 0.4331 - recall@0.5/confusion: 0.3161 - precision@0.5/curiosity: 0.5587 - recall@0.5/curiosity: 0.7117 - precision@0.5/desire: 0.7568 - recall@0.5/desire: 0.3544 - precision@0.5/disappointment: 0.3103 - recall@0.5/disappointment: 0.0625 - precision@0.5/disapproval: 0.5272 - recall@0.5/disapproval: 0.3333 - precision@0.5/disgust: 0.8140 - recall@0.5/disgust: 0.3535 - precision@0.5/embarrassment: 0.7200 - recall@0.5/embarrassment: 0.4615 - precision@0.5/excitement: 0.7619 - recall@0.5/excitement: 0.1649 - precision@0.5/fear: 0.7119 - recall@0.5/fear: 0.4828 - precision@0.5/gratitude: 0.9127 - recall@0.5/gratitude: 0.9025 - precision@0.5/grief: 0.3333 - recall@0.5/grief: 0.6250 - precision@0.5/joy: 0.6345 - recall@0.5/joy: 0.5576 - precision@0.5/love: 0.7176 - recall@0.5/love: 0.9037 - precision@0.5/nervousness: 0.3333 - recall@0.5/nervousness: 0.3529 - precision@0.5/optimism: 0.5707 - recall@0.5/optimism: 0.6140 - precision@0.5/pride: 0.5333 - recall@0.5/pride: 0.7273 - precision@0.5/realization: 0.6389 - recall@0.5/realization: 0.1825 - precision@0.5/relief: 0.1667 - recall@0.5/relief: 0.1765 - precision@0.5/remorse: 0.6494 - recall@0.5/remorse: 0.7576 - precision@0.5/sadness: 0.5600 - recall@0.5/sadness: 0.5283 - precision@0.5/surprise: 0.6098 - recall@0.5/surprise: 0.5319 - precision@0.5/all: 0.6132 - recall@0.5/all: 0.5566 - f1_score@0.5/all: 0.5634 - f1_score_micro@0.5/all: 0.5835 - f1_score_macro@0.5/all: 0.5070
# metric                          value
# ----------------------------  -------
# loss                          0.08944
# precision@0.5/admiration      0.68873
# recall@0.5/admiration         0.73473
# precision@0.5/amusement       0.76567
# recall@0.5/amusement          0.88365
# precision@0.5/anger           0.47297
# recall@0.5/anger              0.52239
# precision@0.5/annoyance       0.31169
# recall@0.5/annoyance          0.32432
# precision@0.5/approval        0.49838
# recall@0.5/approval           0.39386
# precision@0.5/caring          0.51351
# recall@0.5/caring             0.42222
# precision@0.5/confusion       0.43307
# recall@0.5/confusion          0.31609
# precision@0.5/curiosity       0.55866
# recall@0.5/curiosity          0.71174
# precision@0.5/desire          0.75676
# recall@0.5/desire             0.35443
# precision@0.5/disappointment  0.31034
# recall@0.5/disappointment     0.06250
# precision@0.5/disapproval     0.52717
# recall@0.5/disapproval        0.33333
# precision@0.5/disgust         0.81395
# recall@0.5/disgust            0.35354
# precision@0.5/embarrassment   0.72000
# recall@0.5/embarrassment      0.46154
# precision@0.5/excitement      0.76190
# recall@0.5/excitement         0.16495
# precision@0.5/fear            0.71186
# recall@0.5/fear               0.48276
# precision@0.5/gratitude       0.91268
# recall@0.5/gratitude          0.90251
# precision@0.5/grief           0.33333
# recall@0.5/grief              0.62500
# precision@0.5/joy             0.63448
# recall@0.5/joy                0.55758
# precision@0.5/love            0.71765
# recall@0.5/love               0.90370
# precision@0.5/nervousness     0.33333
# recall@0.5/nervousness        0.35294
# precision@0.5/optimism        0.57065
# recall@0.5/optimism           0.61404
# precision@0.5/pride           0.53333
# recall@0.5/pride              0.72727
# precision@0.5/realization     0.63889
# recall@0.5/realization        0.18254
# precision@0.5/relief          0.16667
# recall@0.5/relief             0.17647
# precision@0.5/remorse         0.64935
# recall@0.5/remorse            0.75758
# precision@0.5/sadness         0.56000
# recall@0.5/sadness            0.52830
# precision@0.5/surprise        0.60976
# recall@0.5/surprise           0.53191
# precision@0.5/all             0.61322
# recall@0.5/all                0.55658
# f1_score@0.5/all              0.56341
# f1_score_micro@0.5/all        0.58353
# f1_score_macro@0.5/all        0.50704

# %%
stats = history.history
train_stats = {
    'Train Loss': stats['loss'],
    'Train Precision All': stats['precision@0.5/all'],
    'Train Recall All': stats['recall@0.5/all'],
    'Train F1-Score Weighted': stats['f1_score@0.5/all'],
    'Train F1-Score Micro': stats['f1_score_micro@0.5/all'],
    'Train F1-Score Macro': stats['f1_score_macro@0.5/all'],
}

utils.plot_history(train_stats, title='Model fit history (train)', savepath='./plots/train_hist.png')

# %%
val_stats = {
    'Val Loss': stats['val_loss'],
    'Val Precision All': stats['val_precision@0.5/all'],
    'Val Recall All': stats['val_recall@0.5/all'],
    'Val F1-Score Weighted': stats['val_f1_score@0.5/all'],
    'Val F1-Score Micro': stats['val_f1_score_micro@0.5/all'],
    'Val F1-Score Macro': stats['val_f1_score_macro@0.5/all'],
}
utils.plot_history(val_stats, title='Model fit history (validation)', savepath='./plots/val_hist.png')

# %% [markdown]
# ## Score test and run most-important metrics on emotions prediction

# %%
from tensorflow.keras.metrics import Precision
from tensorflow_addons.metrics import F1Score


test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(), THRESHOLD)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.6132
# F1-Score (micro): 0.5835
# F1-Score (macro): 0.5070

# %% [markdown]
# ## Score test and run most-important metrics on sentiments prediction

# %%
sentiments = utils.load_sentiments(DATASET_DIR)
sentiment_map = utils.map_sentiments(classes, sentiments)
del sentiment_map[27]
test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(),
                           THRESHOLD, sentiment_map)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.8574
# F1-Score (micro): 0.7760
# F1-Score (macro): 0.7349

# %%
utils.test_examples(model, classes)
# Out:
# I am feeling great today!: admiration 👏
# The weather is so good: admiration 👏
# I have performed well at the university:
# The war has started:
# He is desperate in this cruel world:
# I love the feeling when my girlfriend hugs me: love ❤️
# I hate monday mornings: anger 😡
# Merry Christmas! I told Santa you were good this year and asked him to bring you a year full of joy and pleasure : joy 😃
# brilliant! Such a detailed review, it was a pleasure, thank you! Guys, make sure you find time to read :) Aaaaand you can actually choose sth new): admiration 👏 gratitude 🙏
# I have the new pan for pancakes.:
# Relax, bro. Take it easy: relief 😅
# WTF? Are they kidding us? I'm gonna argue with the manager!: annoyance 😒
# OMG, yep!!! That is the final answer! Thank you so much!: gratitude 🙏
# I am so glad this is over: joy 😃
# Sorry, I feel bad for having said that: remorse 😔 sadness 😞
# Happy birthday, my friend! I wish you a lot of success!: desire 😍 joy 😃
# What a shame! I will never talk to him: embarrassment 😳
# What if she knows? We don't know what to do: confusion 😕 curiosity 🤔
# WOW! I am really into cinema: surprise 😲
# What if I don't pass the exam? I will never get this driving license!: confusion 😕 curiosity 🤔
# I miss my grandad. I am feeling so lonely after her death. I just lost my closest person..: sadness 😞
# Skipping lessons is so miserable for Oxford stundets!:
# Have a rest, my boy. You had a long trip. I will make us tea and bring a cake.:
# What a man! My son got the highest rate and will study in Cambridge. Our family is so proud of him!: pride 😌
# Mmmm, delicious. That's totally the best pasta in Italy!: admiration 👏

# %%
utils.plot_conf_mtrx_all(model, test_ds, classes, savepath='./plots/Conf_Mtrx_All_classes.png')

# %%
utils.plot_conf_mtrx_per_class(model, test_ds, classes, savepath='./plots/Conf_Mtrx_per_class.png')

# %%
utils.plot_roc_curves(test_ds, model, classes, './plots/ROC_Curves.png')

# %%
model.save_weights('./models/bert_0_7_1_no_neutral')
