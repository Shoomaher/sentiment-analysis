# %%
from sentiment import utils


DATASET_DIR = './goemotions_data/'
classes = utils.load_classes(DATASET_DIR)
classes.remove('neutral')
classes
# Out:
# ['admiration',
#  'amusement',
#  'anger',
#  'annoyance',
#  'approval',
#  'caring',
#  'confusion',
#  'curiosity',
#  'desire',
#  'disappointment',
#  'disapproval',
#  'disgust',
#  'embarrassment',
#  'excitement',
#  'fear',
#  'gratitude',
#  'grief',
#  'joy',
#  'love',
#  'nervousness',
#  'optimism',
#  'pride',
#  'realization',
#  'relief',
#  'remorse',
#  'sadness',
#  'surprise']

# %%
# %%time
train_df, val_df, test_df = utils.make_dataframes(DATASET_DIR,
                                                  fraction=0.85,
                                                  random=1682284394,
                                                  split_by_class=True,
                                                  drop_neutral=True,
                                                  test_only_singles=True,
                                                  oversample_low=True,
                                                  low_threshold=500)
# Out:
# Random seed: 1682284394
# CPU times: total: 984 ms
# Wall time: 987 ms
# D:\sentiment-analysis\sentiment\utils.py:116: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   class_mask = (df['labels'].str.contains(f'(^|,){label}(,|$)',

# %%
from tensorflow.data import AUTOTUNE

BATCH_SIZE = 64


dataframes = {'Train': train_df, 'Validation': val_df, 'Test': test_df}
for title, df in dataframes.items():
    utils.plot_class_distr(df, classes, title)
train_ds = utils.make_ts_ds(train_df, classes, BATCH_SIZE, AUTOTUNE)
val_ds = utils.make_ts_ds(val_df, classes, BATCH_SIZE, AUTOTUNE)
test_ds = utils.make_ts_ds(test_df, classes, BATCH_SIZE, AUTOTUNE)
# Out:
# D:\sentiment-analysis\sentiment\utils.py:569: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(classes, rotation=45, ha='right')

# %%
from sentiment import bert_model

BERT_MODEL = 'small_bert/bert_en_uncased_L-2_H-128_A-2'


model = bert_model.BertSentimentModel(BERT_MODEL, dropout_rate=0.4,
                                      dense_units=256, classes=classes)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
from official.nlp import optimization  # to create AdamW optimizer
import tensorflow as tf
from tensorflow.keras.losses import BinaryCrossentropy


THRESHOLD = 0.5
EPOCHS = 10
INIT_LR = 3e-4


steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
num_train_steps = steps_per_epoch * EPOCHS
num_warmup_steps = int(0.1*num_train_steps)
optimizer = optimization.create_optimizer(init_lr=INIT_LR,
                                          num_train_steps=num_train_steps,
                                          num_warmup_steps=num_warmup_steps,
                                          optimizer_type='adamw')
metrics = utils.create_metrics(classes, THRESHOLD)
loss = BinaryCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
from tensorflow.keras.callbacks import EarlyStopping


history = model.fit(x=train_ds, validation_data=val_ds, epochs=EPOCHS,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=2)])
# Out:
# Epoch 1/10
# 463/463 [==============================] - 595s 1s/step - loss: 0.3160 - precision@0.5/admiration: 0.1541 - recall@0.5/admiration: 0.0444 - precision@0.5/amusement: 0.0746 - recall@0.5/amusement: 0.1379 - precision@0.5/anger: 0.0533 - recall@0.5/anger: 0.1377 - precision@0.5/annoyance: 0.0811 - recall@0.5/annoyance: 0.1628 - precision@0.5/approval: 0.0950 - recall@0.5/approval: 0.1048 - precision@0.5/caring: 0.0414 - recall@0.5/caring: 0.1250 - precision@0.5/confusion: 0.0421 - recall@0.5/confusion: 0.0803 - precision@0.5/curiosity: 0.1043 - recall@0.5/curiosity: 0.0688 - precision@0.5/desire: 0.0165 - recall@0.5/desire: 0.0959 - precision@0.5/disappointment: 0.0461 - recall@0.5/disappointment: 0.1109 - precision@0.5/disapproval: 0.0577 - recall@0.5/disapproval: 0.0557 - precision@0.5/disgust: 0.0185 - recall@0.5/disgust: 0.0860 - precision@0.5/embarrassment: 0.0183 - recall@0.5/embarrassment: 0.0851 - precision@0.5/excitement: 0.0182 - recall@0.5/excitement: 0.1500 - precision@0.5/fear: 0.0167 - recall@0.5/fear: 0.0780 - precision@0.5/gratitude: 0.1013 - recall@0.5/gratitude: 0.0961 - precision@0.5/grief: 0.0166 - recall@0.5/grief: 0.1335 - precision@0.5/joy: 0.0459 - recall@0.5/joy: 0.0387 - precision@0.5/love: 0.1039 - recall@0.5/love: 0.1143 - precision@0.5/nervousness: 0.0154 - recall@0.5/nervousness: 0.0508 - precision@0.5/optimism: 0.0582 - recall@0.5/optimism: 0.2091 - precision@0.5/pride: 0.0153 - recall@0.5/pride: 0.0318 - precision@0.5/realization: 0.0321 - recall@0.5/realization: 0.0064 - precision@0.5/relief: 0.0201 - recall@0.5/relief: 0.0755 - precision@0.5/remorse: 0.0130 - recall@0.5/remorse: 0.0528 - precision@0.5/sadness: 0.0353 - recall@0.5/sadness: 0.0134 - precision@0.5/surprise: 0.0303 - recall@0.5/surprise: 0.1365 - precision@0.5/all: 0.0487 - recall@0.5/all: 0.0941 - f1_score@0.5/all: 0.0695 - f1_score_micro@0.5/all: 0.0642 - f1_score_macro@0.5/all: 0.0544 - val_loss: 0.1477 - val_precision@0.5/admiration: 0.0000e+00 - val_recall@0.5/admiration: 0.0000e+00 - val_precision@0.5/amusement: 0.0000e+00 - val_recall@0.5/amusement: 0.0000e+00 - val_precision@0.5/anger: 0.0000e+00 - val_recall@0.5/anger: 0.0000e+00 - val_precision@0.5/annoyance: 0.0000e+00 - val_recall@0.5/annoyance: 0.0000e+00 - val_precision@0.5/approval: 0.0000e+00 - val_recall@0.5/approval: 0.0000e+00 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.0000e+00 - val_recall@0.5/curiosity: 0.0000e+00 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.0000e+00 - val_recall@0.5/disapproval: 0.0000e+00 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9909 - val_recall@0.5/gratitude: 0.4898 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.0000e+00 - val_recall@0.5/joy: 0.0000e+00 - val_precision@0.5/love: 0.8266 - val_recall@0.5/love: 0.6687 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.0000e+00 - val_recall@0.5/optimism: 0.0000e+00 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.0000e+00 - val_recall@0.5/remorse: 0.0000e+00 - val_precision@0.5/sadness: 0.0000e+00 - val_recall@0.5/sadness: 0.0000e+00 - val_precision@0.5/surprise: 0.0 ...
# Epoch 2/10
# 463/463 [==============================] - 539s 1s/step - loss: 0.1499 - precision@0.5/admiration: 0.6540 - recall@0.5/admiration: 0.3740 - precision@0.5/amusement: 0.7647 - recall@0.5/amusement: 0.4218 - precision@0.5/anger: 0.3939 - recall@0.5/anger: 0.0259 - precision@0.5/annoyance: 0.3010 - recall@0.5/annoyance: 0.0258 - precision@0.5/approval: 0.2759 - recall@0.5/approval: 0.0141 - precision@0.5/caring: 0.1429 - recall@0.5/caring: 0.0018 - precision@0.5/confusion: 0.2517 - recall@0.5/confusion: 0.0289 - precision@0.5/curiosity: 0.6054 - recall@0.5/curiosity: 0.3623 - precision@0.5/desire: 0.8000 - recall@0.5/desire: 0.0078 - precision@0.5/disappointment: 0.0476 - recall@0.5/disappointment: 7.7042e-04 - precision@0.5/disapproval: 0.3365 - recall@0.5/disapproval: 0.0181 - precision@0.5/disgust: 0.0000e+00 - recall@0.5/disgust: 0.0000e+00 - precision@0.5/embarrassment: 0.0000e+00 - recall@0.5/embarrassment: 0.0000e+00 - precision@0.5/excitement: 0.0000e+00 - recall@0.5/excitement: 0.0000e+00 - precision@0.5/fear: 0.0000e+00 - recall@0.5/fear: 0.0000e+00 - precision@0.5/gratitude: 0.9249 - recall@0.5/gratitude: 0.7202 - precision@0.5/grief: 0.7857 - recall@0.5/grief: 0.0213 - precision@0.5/joy: 0.4943 - recall@0.5/joy: 0.0623 - precision@0.5/love: 0.7873 - recall@0.5/love: 0.5893 - precision@0.5/nervousness: 0.0000e+00 - recall@0.5/nervousness: 0.0000e+00 - precision@0.5/optimism: 0.6403 - recall@0.5/optimism: 0.0571 - precision@0.5/pride: 0.6333 - recall@0.5/pride: 0.0378 - precision@0.5/realization: 0.0000e+00 - recall@0.5/realization: 0.0000e+00 - precision@0.5/relief: 0.0000e+00 - recall@0.5/relief: 0.0000e+00 - precision@0.5/remorse: 0.4688 - recall@0.5/remorse: 0.0294 - precision@0.5/sadness: 0.5600 - recall@0.5/sadness: 0.0396 - precision@0.5/surprise: 0.3000 - recall@0.5/surprise: 0.0030 - precision@0.5/all: 0.7076 - recall@0.5/all: 0.1828 - f1_score@0.5/all: 0.2287 - f1_score_micro@0.5/all: 0.2905 - f1_score_macro@0.5/all: 0.1352 - val_loss: 0.1116 - val_precision@0.5/admiration: 0.8071 - val_recall@0.5/admiration: 0.5369 - val_precision@0.5/amusement: 0.8289 - val_recall@0.5/amusement: 0.8333 - val_precision@0.5/anger: 0.8077 - val_recall@0.5/anger: 0.0814 - val_precision@0.5/annoyance: 0.0000e+00 - val_recall@0.5/annoyance: 0.0000e+00 - val_precision@0.5/approval: 0.0000e+00 - val_recall@0.5/approval: 0.0000e+00 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.6183 - val_recall@0.5/curiosity: 0.6864 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.0000e+00 - val_recall@0.5/disapproval: 0.0000e+00 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9398 - val_recall@0.5/gratitude: 0.8804 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.6759 - val_recall@0.5/joy: 0.3120 - val_precision@0.5/love: 0.7969 - val_recall@0.5/love: 0.7731 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.7400 - val_recall@0.5/optimism: 0.4319 - val_precision@0.5/pride: 1.0000 - val_recall@0.5/pride: 0.1176 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6000 - val_recall@0.5/remorse: 0.1429 - val_precision@0.5/sadness: 0.7143 - val_recall@0.5/sadness: 0.3828 - val_precision@0.5/surprise: 0.0000e+00 - va ...
# Epoch 3/10
# 463/463 [==============================] - 529s 1s/step - loss: 0.1252 - precision@0.5/admiration: 0.7314 - recall@0.5/admiration: 0.5532 - precision@0.5/amusement: 0.8107 - recall@0.5/amusement: 0.6985 - precision@0.5/anger: 0.5584 - recall@0.5/anger: 0.1876 - precision@0.5/annoyance: 0.3506 - recall@0.5/annoyance: 0.0733 - precision@0.5/approval: 0.4450 - recall@0.5/approval: 0.0626 - precision@0.5/caring: 0.4655 - recall@0.5/caring: 0.0245 - precision@0.5/confusion: 0.2991 - recall@0.5/confusion: 0.0523 - precision@0.5/curiosity: 0.6291 - recall@0.5/curiosity: 0.4532 - precision@0.5/desire: 0.7069 - recall@0.5/desire: 0.0802 - precision@0.5/disappointment: 0.3750 - recall@0.5/disappointment: 0.0116 - precision@0.5/disapproval: 0.4096 - recall@0.5/disapproval: 0.0572 - precision@0.5/disgust: 0.3333 - recall@0.5/disgust: 0.0080 - precision@0.5/embarrassment: 0.7609 - recall@0.5/embarrassment: 0.0677 - precision@0.5/excitement: 0.1818 - recall@0.5/excitement: 0.0040 - precision@0.5/fear: 0.7073 - recall@0.5/fear: 0.0565 - precision@0.5/gratitude: 0.9246 - recall@0.5/gratitude: 0.8193 - precision@0.5/grief: 0.7619 - recall@0.5/grief: 0.1238 - precision@0.5/joy: 0.5753 - recall@0.5/joy: 0.2135 - precision@0.5/love: 0.7966 - recall@0.5/love: 0.6913 - precision@0.5/nervousness: 0.3333 - recall@0.5/nervousness: 0.0113 - precision@0.5/optimism: 0.7348 - recall@0.5/optimism: 0.2720 - precision@0.5/pride: 0.8403 - recall@0.5/pride: 0.2406 - precision@0.5/realization: 0.0000e+00 - recall@0.5/realization: 0.0000e+00 - precision@0.5/relief: 0.2500 - recall@0.5/relief: 0.0020 - precision@0.5/remorse: 0.6256 - recall@0.5/remorse: 0.2387 - precision@0.5/sadness: 0.6283 - recall@0.5/sadness: 0.2201 - precision@0.5/surprise: 0.5575 - recall@0.5/surprise: 0.0959 - precision@0.5/all: 0.7158 - recall@0.5/all: 0.2883 - f1_score@0.5/all: 0.3474 - f1_score_micro@0.5/all: 0.4110 - f1_score_macro@0.5/all: 0.2533 - val_loss: 0.1042 - val_precision@0.5/admiration: 0.7890 - val_recall@0.5/admiration: 0.5516 - val_precision@0.5/amusement: 0.8193 - val_recall@0.5/amusement: 0.8519 - val_precision@0.5/anger: 0.5430 - val_recall@0.5/anger: 0.4651 - val_precision@0.5/annoyance: 0.4468 - val_recall@0.5/annoyance: 0.1544 - val_precision@0.5/approval: 0.6234 - val_recall@0.5/approval: 0.0992 - val_precision@0.5/caring: 0.8333 - val_recall@0.5/caring: 0.0556 - val_precision@0.5/confusion: 1.0000 - val_recall@0.5/confusion: 0.0229 - val_precision@0.5/curiosity: 0.6371 - val_recall@0.5/curiosity: 0.6299 - val_precision@0.5/desire: 0.7381 - val_recall@0.5/desire: 0.3069 - val_precision@0.5/disappointment: 1.0000 - val_recall@0.5/disappointment: 0.0049 - val_precision@0.5/disapproval: 0.7812 - val_recall@0.5/disapproval: 0.0744 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.6667 - val_recall@0.5/embarrassment: 0.4348 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.7500 - val_recall@0.5/fear: 0.3030 - val_precision@0.5/gratitude: 0.9467 - val_recall@0.5/gratitude: 0.8826 - val_precision@0.5/grief: 0.2143 - val_recall@0.5/grief: 0.3333 - val_precision@0.5/joy: 0.6772 - val_recall@0.5/joy: 0.3675 - val_precision@0.5/love: 0.7746 - val_recall@0.5/love: 0.8209 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.7605 - val_recall@0.5/optimism: 0.4942 - val_precision@0.5/pride: 0.5556 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6984 - val_recall@0.5/remorse: 0.5238 - val_precision@0.5/sadness: 0.6875 - val_recall@0.5/sadness: 0.4211 - val_precision@0.5/surprise: 0.6250 - val_recall@0.5/surprise: 0.4070 - val_precision@0.5/all: 0.7364 - val_recall@0.5/all: 0.3933 - val_f1_score@0.5/all: 0.4436 - val_f1_score ...
# Epoch 4/10
# 463/463 [==============================] - 533s 1s/step - loss: 0.1117 - precision@0.5/admiration: 0.7598 - recall@0.5/admiration: 0.6051 - precision@0.5/amusement: 0.8134 - recall@0.5/amusement: 0.7310 - precision@0.5/anger: 0.6135 - recall@0.5/anger: 0.3074 - precision@0.5/annoyance: 0.4281 - recall@0.5/annoyance: 0.1204 - precision@0.5/approval: 0.5511 - recall@0.5/approval: 0.1270 - precision@0.5/caring: 0.5735 - recall@0.5/caring: 0.1060 - precision@0.5/confusion: 0.3870 - recall@0.5/confusion: 0.0881 - precision@0.5/curiosity: 0.6570 - recall@0.5/curiosity: 0.5110 - precision@0.5/desire: 0.6783 - recall@0.5/desire: 0.1526 - precision@0.5/disappointment: 0.3982 - recall@0.5/disappointment: 0.0347 - precision@0.5/disapproval: 0.4771 - recall@0.5/disapproval: 0.1129 - precision@0.5/disgust: 0.4906 - recall@0.5/disgust: 0.0520 - precision@0.5/embarrassment: 0.7871 - recall@0.5/embarrassment: 0.2360 - precision@0.5/excitement: 0.0000e+00 - recall@0.5/excitement: 0.0000e+00 - precision@0.5/fear: 0.7500 - recall@0.5/fear: 0.2690 - precision@0.5/gratitude: 0.9290 - recall@0.5/gratitude: 0.8398 - precision@0.5/grief: 0.7834 - recall@0.5/grief: 0.3288 - precision@0.5/joy: 0.6108 - recall@0.5/joy: 0.2844 - precision@0.5/love: 0.8157 - recall@0.5/love: 0.7408 - precision@0.5/nervousness: 0.6525 - recall@0.5/nervousness: 0.1450 - precision@0.5/optimism: 0.7433 - recall@0.5/optimism: 0.3752 - precision@0.5/pride: 0.8921 - recall@0.5/pride: 0.4274 - precision@0.5/realization: 0.6471 - recall@0.5/realization: 0.0100 - precision@0.5/relief: 0.2500 - recall@0.5/relief: 0.0040 - precision@0.5/remorse: 0.6537 - recall@0.5/remorse: 0.3953 - precision@0.5/sadness: 0.6408 - recall@0.5/sadness: 0.3093 - precision@0.5/surprise: 0.6207 - recall@0.5/surprise: 0.2315 - precision@0.5/all: 0.7249 - recall@0.5/all: 0.3545 - f1_score@0.5/all: 0.4250 - f1_score_micro@0.5/all: 0.4762 - f1_score_macro@0.5/all: 0.3553 - val_loss: 0.1025 - val_precision@0.5/admiration: 0.7769 - val_recall@0.5/admiration: 0.5959 - val_precision@0.5/amusement: 0.8260 - val_recall@0.5/amusement: 0.8413 - val_precision@0.5/anger: 0.4877 - val_recall@0.5/anger: 0.5388 - val_precision@0.5/annoyance: 0.4235 - val_recall@0.5/annoyance: 0.2647 - val_precision@0.5/approval: 0.4459 - val_recall@0.5/approval: 0.2045 - val_precision@0.5/caring: 0.5208 - val_recall@0.5/caring: 0.1389 - val_precision@0.5/confusion: 0.6327 - val_recall@0.5/confusion: 0.1422 - val_precision@0.5/curiosity: 0.6445 - val_recall@0.5/curiosity: 0.6299 - val_precision@0.5/desire: 0.7193 - val_recall@0.5/desire: 0.4059 - val_precision@0.5/disappointment: 0.3846 - val_recall@0.5/disappointment: 0.0728 - val_precision@0.5/disapproval: 0.6100 - val_recall@0.5/disapproval: 0.1815 - val_precision@0.5/disgust: 0.8333 - val_recall@0.5/disgust: 0.0746 - val_precision@0.5/embarrassment: 0.5789 - val_recall@0.5/embarrassment: 0.4783 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.6389 - val_recall@0.5/fear: 0.4646 - val_precision@0.5/gratitude: 0.9489 - val_recall@0.5/gratitude: 0.8804 - val_precision@0.5/grief: 0.2143 - val_recall@0.5/grief: 0.6667 - val_precision@0.5/joy: 0.6978 - val_recall@0.5/joy: 0.4145 - val_precision@0.5/love: 0.7790 - val_recall@0.5/love: 0.8418 - val_precision@0.5/nervousness: 0.5882 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.7322 - val_recall@0.5/optimism: 0.5214 - val_precision@0.5/pride: 0.5000 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6974 - val_recall@0.5/remorse: 0.6310 - val_precision@0.5/sadness: 0.5654 - val_recall@0.5/sadness: 0.5167 - val_precision@0.5/surprise: 0.6391 - val_recall@0.5/surprise: 0.4942 - val_precision@0.5/all: 0.6817 - val_recall@0.5/all: 0.4518 - val_f1_score@0.5/all: 0.4990 - val_f1_score_micro@0.5/all:  ...
# Epoch 5/10
# 463/463 [==============================] - 530s 1s/step - loss: 0.1018 - precision@0.5/admiration: 0.7870 - recall@0.5/admiration: 0.6537 - precision@0.5/amusement: 0.8318 - recall@0.5/amusement: 0.7535 - precision@0.5/anger: 0.6370 - recall@0.5/anger: 0.3619 - precision@0.5/annoyance: 0.4904 - recall@0.5/annoyance: 0.1695 - precision@0.5/approval: 0.6083 - recall@0.5/approval: 0.2114 - precision@0.5/caring: 0.6491 - recall@0.5/caring: 0.1676 - precision@0.5/confusion: 0.4757 - recall@0.5/confusion: 0.1373 - precision@0.5/curiosity: 0.7014 - recall@0.5/curiosity: 0.5669 - precision@0.5/desire: 0.7861 - recall@0.5/desire: 0.2661 - precision@0.5/disappointment: 0.5323 - recall@0.5/disappointment: 0.0824 - precision@0.5/disapproval: 0.5806 - recall@0.5/disapproval: 0.1764 - precision@0.5/disgust: 0.6075 - recall@0.5/disgust: 0.1300 - precision@0.5/embarrassment: 0.8104 - recall@0.5/embarrassment: 0.3308 - precision@0.5/excitement: 0.2941 - recall@0.5/excitement: 0.0100 - precision@0.5/fear: 0.7633 - recall@0.5/fear: 0.3645 - precision@0.5/gratitude: 0.9366 - recall@0.5/gratitude: 0.8470 - precision@0.5/grief: 0.8651 - recall@0.5/grief: 0.5706 - precision@0.5/joy: 0.6200 - recall@0.5/joy: 0.3424 - precision@0.5/love: 0.8243 - recall@0.5/love: 0.7490 - precision@0.5/nervousness: 0.7831 - recall@0.5/nervousness: 0.3672 - precision@0.5/optimism: 0.7254 - recall@0.5/optimism: 0.4067 - precision@0.5/pride: 0.9006 - recall@0.5/pride: 0.5586 - precision@0.5/realization: 0.4722 - recall@0.5/realization: 0.0155 - precision@0.5/relief: 0.7073 - recall@0.5/relief: 0.0577 - precision@0.5/remorse: 0.6571 - recall@0.5/remorse: 0.4462 - precision@0.5/sadness: 0.6990 - recall@0.5/sadness: 0.4027 - precision@0.5/surprise: 0.6781 - recall@0.5/surprise: 0.3333 - precision@0.5/all: 0.7454 - recall@0.5/all: 0.4111 - f1_score@0.5/all: 0.4886 - f1_score_micro@0.5/all: 0.5300 - f1_score_macro@0.5/all: 0.4365 - val_loss: 0.1013 - val_precision@0.5/admiration: 0.7517 - val_recall@0.5/admiration: 0.6431 - val_precision@0.5/amusement: 0.8294 - val_recall@0.5/amusement: 0.8360 - val_precision@0.5/anger: 0.5144 - val_recall@0.5/anger: 0.4845 - val_precision@0.5/annoyance: 0.4250 - val_recall@0.5/annoyance: 0.2917 - val_precision@0.5/approval: 0.4530 - val_recall@0.5/approval: 0.2190 - val_precision@0.5/caring: 0.5070 - val_recall@0.5/caring: 0.2000 - val_precision@0.5/confusion: 0.5634 - val_recall@0.5/confusion: 0.1835 - val_precision@0.5/curiosity: 0.6338 - val_recall@0.5/curiosity: 0.6356 - val_precision@0.5/desire: 0.6852 - val_recall@0.5/desire: 0.3663 - val_precision@0.5/disappointment: 0.3667 - val_recall@0.5/disappointment: 0.1068 - val_precision@0.5/disapproval: 0.4977 - val_recall@0.5/disapproval: 0.3244 - val_precision@0.5/disgust: 0.7391 - val_recall@0.5/disgust: 0.1269 - val_precision@0.5/embarrassment: 0.5897 - val_recall@0.5/embarrassment: 0.5000 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.7167 - val_recall@0.5/fear: 0.4343 - val_precision@0.5/gratitude: 0.9424 - val_recall@0.5/gratitude: 0.8871 - val_precision@0.5/grief: 0.1818 - val_recall@0.5/grief: 0.4444 - val_precision@0.5/joy: 0.6879 - val_recall@0.5/joy: 0.4615 - val_precision@0.5/love: 0.7765 - val_recall@0.5/love: 0.8299 - val_precision@0.5/nervousness: 0.4737 - val_recall@0.5/nervousness: 0.3750 - val_precision@0.5/optimism: 0.7389 - val_recall@0.5/optimism: 0.5175 - val_precision@0.5/pride: 0.5000 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 1.0000 - val_recall@0.5/realization: 0.0167 - val_precision@0.5/relief: 0.8000 - val_recall@0.5/relief: 0.1739 - val_precision@0.5/remorse: 0.6747 - val_recall@0.5/remorse: 0.6667 - val_precision@0.5/sadness: 0.6059 - val_recall@0.5/sadness: 0.4928 - val_precision@0.5/surprise: 0.6014 - val_recall@0.5/surprise: 0.5174 - val_precision@0.5/all: 0.6693 - val_recall@0.5/all: 0.4729 - val_f1_score@0.5/all: 0.5184 - val_f1_score_micro@0.5/all: 0.5542 - val_f1_score_ma ...
# Epoch 6/10
# 463/463 [==============================] - 530s 1s/step - loss: 0.0932 - precision@0.5/admiration: 0.8187 - recall@0.5/admiration: 0.6930 - precision@0.5/amusement: 0.8407 - recall@0.5/amusement: 0.7751 - precision@0.5/anger: 0.6346 - recall@0.5/anger: 0.4032 - precision@0.5/annoyance: 0.5093 - recall@0.5/annoyance: 0.2278 - precision@0.5/approval: 0.6947 - recall@0.5/approval: 0.2962 - precision@0.5/caring: 0.6402 - recall@0.5/caring: 0.2482 - precision@0.5/confusion: 0.5475 - recall@0.5/confusion: 0.1934 - precision@0.5/curiosity: 0.7224 - recall@0.5/curiosity: 0.5970 - precision@0.5/desire: 0.7752 - recall@0.5/desire: 0.3307 - precision@0.5/disappointment: 0.6055 - recall@0.5/disappointment: 0.1348 - precision@0.5/disapproval: 0.6213 - recall@0.5/disapproval: 0.2682 - precision@0.5/disgust: 0.5988 - recall@0.5/disgust: 0.1940 - precision@0.5/embarrassment: 0.8178 - recall@0.5/embarrassment: 0.4255 - precision@0.5/excitement: 0.6061 - recall@0.5/excitement: 0.0400 - precision@0.5/fear: 0.7910 - recall@0.5/fear: 0.4795 - precision@0.5/gratitude: 0.9418 - recall@0.5/gratitude: 0.8595 - precision@0.5/grief: 0.8625 - recall@0.5/grief: 0.6673 - precision@0.5/joy: 0.6910 - recall@0.5/joy: 0.4004 - precision@0.5/love: 0.8392 - recall@0.5/love: 0.7724 - precision@0.5/nervousness: 0.8099 - recall@0.5/nervousness: 0.5217 - precision@0.5/optimism: 0.7627 - recall@0.5/optimism: 0.4349 - precision@0.5/pride: 0.9164 - recall@0.5/pride: 0.6541 - precision@0.5/realization: 0.6056 - recall@0.5/realization: 0.0392 - precision@0.5/relief: 0.6701 - recall@0.5/relief: 0.1292 - precision@0.5/remorse: 0.6802 - recall@0.5/remorse: 0.5245 - precision@0.5/sadness: 0.7296 - recall@0.5/sadness: 0.4487 - precision@0.5/surprise: 0.6882 - recall@0.5/surprise: 0.3996 - precision@0.5/all: 0.7617 - recall@0.5/all: 0.4634 - f1_score@0.5/all: 0.5436 - f1_score_micro@0.5/all: 0.5762 - f1_score_macro@0.5/all: 0.5007 - val_loss: 0.1034 - val_precision@0.5/admiration: 0.7470 - val_recall@0.5/admiration: 0.6490 - val_precision@0.5/amusement: 0.7862 - val_recall@0.5/amusement: 0.8757 - val_precision@0.5/anger: 0.4762 - val_recall@0.5/anger: 0.5039 - val_precision@0.5/annoyance: 0.4271 - val_recall@0.5/annoyance: 0.3088 - val_precision@0.5/approval: 0.4703 - val_recall@0.5/approval: 0.2293 - val_precision@0.5/caring: 0.5143 - val_recall@0.5/caring: 0.2000 - val_precision@0.5/confusion: 0.5055 - val_recall@0.5/confusion: 0.2110 - val_precision@0.5/curiosity: 0.6552 - val_recall@0.5/curiosity: 0.5904 - val_precision@0.5/desire: 0.6885 - val_recall@0.5/desire: 0.4158 - val_precision@0.5/disappointment: 0.2872 - val_recall@0.5/disappointment: 0.1311 - val_precision@0.5/disapproval: 0.5581 - val_recall@0.5/disapproval: 0.2857 - val_precision@0.5/disgust: 0.6667 - val_recall@0.5/disgust: 0.2239 - val_precision@0.5/embarrassment: 0.5111 - val_recall@0.5/embarrassment: 0.5000 - val_precision@0.5/excitement: 1.0000 - val_recall@0.5/excitement: 0.0441 - val_precision@0.5/fear: 0.6623 - val_recall@0.5/fear: 0.5152 - val_precision@0.5/gratitude: 0.9365 - val_recall@0.5/gratitude: 0.8984 - val_precision@0.5/grief: 0.2105 - val_recall@0.5/grief: 0.4444 - val_precision@0.5/joy: 0.6550 - val_recall@0.5/joy: 0.4786 - val_precision@0.5/love: 0.7824 - val_recall@0.5/love: 0.8478 - val_precision@0.5/nervousness: 0.4545 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.6733 - val_recall@0.5/optimism: 0.5292 - val_precision@0.5/pride: 0.4167 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.6364 - val_recall@0.5/realization: 0.0389 - val_precision@0.5/relief: 0.6000 - val_recall@0.5/relief: 0.2609 - val_precision@0.5/remorse: 0.6556 - val_recall@0.5/remorse: 0.7024 - val_precision@0.5/sadness: 0.5598 - val_recall@0.5/sadness: 0.4928 - val_precision@0.5/surprise: 0.5814 - val_recall@0.5/surprise: 0.5814 - val_precision@0.5/all: 0.6543 - val_recall@0.5/all: 0.4878 - val_f1_score@0.5/all: 0.5270 - val_f1_score_micro@0.5/all: 0.5589 - val_f1_score_macro@0.5/ ...
# Epoch 7/10
# 463/463 [==============================] - 530s 1s/step - loss: 0.0867 - precision@0.5/admiration: 0.8268 - recall@0.5/admiration: 0.7220 - precision@0.5/amusement: 0.8619 - recall@0.5/amusement: 0.7990 - precision@0.5/anger: 0.6726 - recall@0.5/anger: 0.4744 - precision@0.5/annoyance: 0.5500 - recall@0.5/annoyance: 0.2632 - precision@0.5/approval: 0.7149 - recall@0.5/approval: 0.3563 - precision@0.5/caring: 0.6734 - recall@0.5/caring: 0.3025 - precision@0.5/confusion: 0.6007 - recall@0.5/confusion: 0.2512 - precision@0.5/curiosity: 0.7530 - recall@0.5/curiosity: 0.6396 - precision@0.5/desire: 0.8307 - recall@0.5/desire: 0.4129 - precision@0.5/disappointment: 0.6311 - recall@0.5/disappointment: 0.1687 - precision@0.5/disapproval: 0.6545 - recall@0.5/disapproval: 0.3332 - precision@0.5/disgust: 0.6543 - recall@0.5/disgust: 0.2460 - precision@0.5/embarrassment: 0.8251 - recall@0.5/embarrassment: 0.4836 - precision@0.5/excitement: 0.5000 - recall@0.5/excitement: 0.0540 - precision@0.5/fear: 0.8393 - recall@0.5/fear: 0.5497 - precision@0.5/gratitude: 0.9443 - recall@0.5/gratitude: 0.8751 - precision@0.5/grief: 0.9114 - recall@0.5/grief: 0.7563 - precision@0.5/joy: 0.7095 - recall@0.5/joy: 0.4355 - precision@0.5/love: 0.8507 - recall@0.5/love: 0.7939 - precision@0.5/nervousness: 0.8245 - recall@0.5/nervousness: 0.5838 - precision@0.5/optimism: 0.7720 - recall@0.5/optimism: 0.4888 - precision@0.5/pride: 0.9015 - recall@0.5/pride: 0.7097 - precision@0.5/realization: 0.6238 - recall@0.5/realization: 0.0574 - precision@0.5/relief: 0.7914 - recall@0.5/relief: 0.2565 - precision@0.5/remorse: 0.7243 - recall@0.5/remorse: 0.5656 - precision@0.5/sadness: 0.7549 - recall@0.5/sadness: 0.5209 - precision@0.5/surprise: 0.7356 - recall@0.5/surprise: 0.4679 - precision@0.5/all: 0.7796 - recall@0.5/all: 0.5085 - f1_score@0.5/all: 0.5875 - f1_score_micro@0.5/all: 0.6155 - f1_score_macro@0.5/all: 0.5529 - val_loss: 0.1044 - val_precision@0.5/admiration: 0.7441 - val_recall@0.5/admiration: 0.6519 - val_precision@0.5/amusement: 0.8024 - val_recall@0.5/amusement: 0.8704 - val_precision@0.5/anger: 0.4963 - val_recall@0.5/anger: 0.5155 - val_precision@0.5/annoyance: 0.4295 - val_recall@0.5/annoyance: 0.3137 - val_precision@0.5/approval: 0.4216 - val_recall@0.5/approval: 0.2335 - val_precision@0.5/caring: 0.4433 - val_recall@0.5/caring: 0.2389 - val_precision@0.5/confusion: 0.4444 - val_recall@0.5/confusion: 0.2752 - val_precision@0.5/curiosity: 0.6377 - val_recall@0.5/curiosity: 0.6017 - val_precision@0.5/desire: 0.7000 - val_recall@0.5/desire: 0.4158 - val_precision@0.5/disappointment: 0.3012 - val_recall@0.5/disappointment: 0.1214 - val_precision@0.5/disapproval: 0.4469 - val_recall@0.5/disapproval: 0.3631 - val_precision@0.5/disgust: 0.6452 - val_recall@0.5/disgust: 0.2985 - val_precision@0.5/embarrassment: 0.5641 - val_recall@0.5/embarrassment: 0.4783 - val_precision@0.5/excitement: 0.8182 - val_recall@0.5/excitement: 0.0662 - val_precision@0.5/fear: 0.7013 - val_recall@0.5/fear: 0.5455 - val_precision@0.5/gratitude: 0.9402 - val_recall@0.5/gratitude: 0.8871 - val_precision@0.5/grief: 0.2353 - val_recall@0.5/grief: 0.4444 - val_precision@0.5/joy: 0.6590 - val_recall@0.5/joy: 0.4872 - val_precision@0.5/love: 0.7637 - val_recall@0.5/love: 0.8299 - val_precision@0.5/nervousness: 0.4762 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.6750 - val_recall@0.5/optimism: 0.5253 - val_precision@0.5/pride: 0.5000 - val_recall@0.5/pride: 0.2941 - val_precision@0.5/realization: 0.6087 - val_recall@0.5/realization: 0.0778 - val_precision@0.5/relief: 0.5556 - val_recall@0.5/relief: 0.2174 - val_precision@0.5/remorse: 0.6824 - val_recall@0.5/remorse: 0.6905 - val_precision@0.5/sadness: 0.5562 - val_recall@0.5/sadness: 0.4737 - val_precision@0.5/surprise: 0.6093 - val_recall@0.5/surprise: 0.5349 - val_precision@0.5/all: 0.6402 - val_recall@0.5/all: 0.4968 - val_f1_score@0.5/all: 0.5342 - val_f1_score_micro@0.5/all: 0.5594 - val_f1_score_macro@0.5/ ...

# %%
eval_metrics = model.evaluate(x=test_ds, return_dict=True)
utils.print_metrics(eval_metrics)
# Out:
# 73/73 [==============================] - 21s 285ms/step - loss: 0.0883 - precision@0.5/admiration: 0.6808 - recall@0.5/admiration: 0.7366 - precision@0.5/amusement: 0.7707 - recall@0.5/amusement: 0.8774 - precision@0.5/anger: 0.4977 - recall@0.5/anger: 0.5373 - precision@0.5/annoyance: 0.3320 - recall@0.5/annoyance: 0.2838 - precision@0.5/approval: 0.5073 - recall@0.5/approval: 0.3555 - precision@0.5/caring: 0.5214 - recall@0.5/caring: 0.4519 - precision@0.5/confusion: 0.4026 - recall@0.5/confusion: 0.3563 - precision@0.5/curiosity: 0.5873 - recall@0.5/curiosity: 0.6940 - precision@0.5/desire: 0.6538 - recall@0.5/desire: 0.4304 - precision@0.5/disappointment: 0.2857 - recall@0.5/disappointment: 0.1389 - precision@0.5/disapproval: 0.4856 - recall@0.5/disapproval: 0.4055 - precision@0.5/disgust: 0.7059 - recall@0.5/disgust: 0.3636 - precision@0.5/embarrassment: 0.7407 - recall@0.5/embarrassment: 0.5128 - precision@0.5/excitement: 0.9231 - recall@0.5/excitement: 0.1237 - precision@0.5/fear: 0.7742 - recall@0.5/fear: 0.5517 - precision@0.5/gratitude: 0.9176 - recall@0.5/gratitude: 0.8997 - precision@0.5/grief: 0.4444 - recall@0.5/grief: 0.5000 - precision@0.5/joy: 0.6405 - recall@0.5/joy: 0.5939 - precision@0.5/love: 0.7387 - recall@0.5/love: 0.9111 - precision@0.5/nervousness: 0.2632 - recall@0.5/nervousness: 0.2941 - precision@0.5/optimism: 0.5852 - recall@0.5/optimism: 0.6023 - precision@0.5/pride: 0.5333 - recall@0.5/pride: 0.7273 - precision@0.5/realization: 0.6429 - recall@0.5/realization: 0.1429 - precision@0.5/relief: 0.1818 - recall@0.5/relief: 0.1176 - precision@0.5/remorse: 0.6279 - recall@0.5/remorse: 0.8182 - precision@0.5/sadness: 0.4815 - recall@0.5/sadness: 0.5723 - precision@0.5/surprise: 0.5745 - recall@0.5/surprise: 0.5745 - precision@0.5/all: 0.6119 - recall@0.5/all: 0.5647 - f1_score@0.5/all: 0.5684 - f1_score_micro@0.5/all: 0.5874 - f1_score_macro@0.5/all: 0.5128
# metric                          value
# ----------------------------  -------
# loss                          0.08826
# precision@0.5/admiration      0.68078
# recall@0.5/admiration         0.73664
# precision@0.5/amusement       0.77072
# recall@0.5/amusement          0.87736
# precision@0.5/anger           0.49770
# recall@0.5/anger              0.53731
# precision@0.5/annoyance       0.33202
# recall@0.5/annoyance          0.28378
# precision@0.5/approval        0.50730
# recall@0.5/approval           0.35550
# precision@0.5/caring          0.52137
# recall@0.5/caring             0.45185
# precision@0.5/confusion       0.40260
# recall@0.5/confusion          0.35632
# precision@0.5/curiosity       0.58735
# recall@0.5/curiosity          0.69395
# precision@0.5/desire          0.65385
# recall@0.5/desire             0.43038
# precision@0.5/disappointment  0.28571
# recall@0.5/disappointment     0.13889
# precision@0.5/disapproval     0.48560
# recall@0.5/disapproval        0.40550
# precision@0.5/disgust         0.70588
# recall@0.5/disgust            0.36364
# precision@0.5/embarrassment   0.74074
# recall@0.5/embarrassment      0.51282
# precision@0.5/excitement      0.92308
# recall@0.5/excitement         0.12371
# precision@0.5/fear            0.77419
# recall@0.5/fear               0.55172
# precision@0.5/gratitude       0.91761
# recall@0.5/gratitude          0.89972
# precision@0.5/grief           0.44444
# recall@0.5/grief              0.50000
# precision@0.5/joy             0.64052
# recall@0.5/joy                0.59394
# precision@0.5/love            0.73874
# recall@0.5/love               0.91111
# precision@0.5/nervousness     0.26316
# recall@0.5/nervousness        0.29412
# precision@0.5/optimism        0.58523
# recall@0.5/optimism           0.60234
# precision@0.5/pride           0.53333
# recall@0.5/pride              0.72727
# precision@0.5/realization     0.64286
# recall@0.5/realization        0.14286
# precision@0.5/relief          0.18182
# recall@0.5/relief             0.11765
# precision@0.5/remorse         0.62791
# recall@0.5/remorse            0.81818
# precision@0.5/sadness         0.48148
# recall@0.5/sadness            0.57233
# precision@0.5/surprise        0.57447
# recall@0.5/surprise           0.57447
# precision@0.5/all             0.61194
# recall@0.5/all                0.56472
# f1_score@0.5/all              0.56844
# f1_score_micro@0.5/all        0.58738
# f1_score_macro@0.5/all        0.51284

# %%
stats = history.history
stats_plots = {
    'Val Loss': stats['val_loss'],
    'Val Precision All': stats['precision@0.5/all'],
    'Val Recall All': stats['recall@0.5/all'],
    'Val F1-Score Weighted': stats['f1_score@0.5/all'],
    'Val F1-Score Micro': stats['f1_score_micro@0.5/all'],
    'Val F1-Score Macro': stats['f1_score_macro@0.5/all'],
}
utils.plot_history(stats_plots)

# %% [markdown]
# ## Score test and run most-important metrics on emotions prediction

# %%
from tensorflow.keras.metrics import Precision
from tensorflow_addons.metrics import F1Score


test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(), THRESHOLD)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.6119
# F1-Score (micro): 0.5874
# F1-Score (macro): 0.5128

# %% [markdown]
# ## Score test and run most-important metrics on sentiments prediction

# %%
sentiments = utils.load_sentiments(DATASET_DIR)
sentiment_map = utils.map_sentiments(classes, sentiments)
del sentiment_map[27]
test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(),
                           THRESHOLD, sentiment_map)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.8527
# F1-Score (micro): 0.7797
# F1-Score (macro): 0.7396

# %%
utils.test_examples(model, classes)
# Out:
# I am feeling great today!: admiration 👏
# The weather is so good: admiration 👏
# I have performed well at the university:
# The war has started:
# He is desperate in this cruel world: disgust 🤮
# I love the feeling when my girlfriend hugs me: love ❤️
# I hate monday mornings: anger 😡
# Merry Christmas! I told Santa you were good this year and asked him to bring you a year full of joy and pleasure : joy 😃
# brilliant! Such a detailed review, it was a pleasure, thank you! Guys, make sure you find time to read :) Aaaaand you can actually choose sth new): admiration 👏 gratitude 🙏
# I have the new pan for pancakes.: approval 👍
# Relax, bro. Take it easy: approval 👍 relief 😅
# WTF? Are they kidding us? I'm gonna argue with the manager!:
# OMG, yep!!! That is the final answer! Thank you so much!: gratitude 🙏
# I am so glad this is over: joy 😃
# Sorry, I feel bad for having said that: remorse 😔 sadness 😞
# Happy birthday, my friend! I wish you a lot of success!: joy 😃
# What a shame! I will never talk to him: embarrassment 😳
# What if she knows? We don't know what to do: confusion 😕 curiosity 🤔
# WOW! I am really into cinema: surprise 😲
# What if I don't pass the exam? I will never get this driving license!: confusion 😕 curiosity 🤔
# I miss my grandad. I am feeling so lonely after her death. I just lost my closest person..: sadness 😞
# Skipping lessons is so miserable for Oxford stundets!:
# Have a rest, my boy. You had a long trip. I will make us tea and bring a cake.: optimism 🤞
# What a man! My son got the highest rate and will study in Cambridge. Our family is so proud of him!: admiration 👏 pride 😌
# Mmmm, delicious. That's totally the best pasta in Italy!: admiration 👏

# %%
utils.plot_conf_mtrx_all(model, test_ds, classes)

# %%
utils.plot_conf_mtrx_per_class(model, test_ds, classes)
# Out:
# 2/2 [==============================] - 1s 155ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 1s 118ms/step

# %%
model.save_weights('./models/bert_0_7_1_no_neutral')

# %% [markdown]
# # Compare modelling results with README
