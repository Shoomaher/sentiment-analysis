# %%
from sentiment import utils


DATASET_DIR = './goemotions_data/'
classes = utils.load_classes(DATASET_DIR)
classes.remove('neutral')
classes
# Out:
# ['admiration',
#  'amusement',
#  'anger',
#  'annoyance',
#  'approval',
#  'caring',
#  'confusion',
#  'curiosity',
#  'desire',
#  'disappointment',
#  'disapproval',
#  'disgust',
#  'embarrassment',
#  'excitement',
#  'fear',
#  'gratitude',
#  'grief',
#  'joy',
#  'love',
#  'nervousness',
#  'optimism',
#  'pride',
#  'realization',
#  'relief',
#  'remorse',
#  'sadness',
#  'surprise']

# %%
# %%time
train_df, val_df, test_df = utils.make_dataframes(DATASET_DIR,
                                                  fraction=0.85,
                                                  random=1682284394,
                                                  split_by_class=True,
                                                  drop_neutral=True,
                                                  test_only_singles=True,
                                                  oversample_low=True,
                                                  low_threshold=500)
# Out:
# Random seed: 1682284394
# D:\sentiment-analysis\sentiment\utils.py:116: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   class_mask = (df['labels'].str.contains(f'(^|,){label}(,|$)',
# CPU times: total: 1.42 s
# Wall time: 1.68 s

# %%
from tensorflow.data import AUTOTUNE

BATCH_SIZE = 64


dataframes = {'Train': train_df, 'Validation': val_df, 'Test': test_df}
for title, df in dataframes.items():
    utils.plot_class_distr(df, classes, title)
train_ds = utils.make_ts_ds(train_df, classes, BATCH_SIZE, AUTOTUNE)
val_ds = utils.make_ts_ds(val_df, classes, BATCH_SIZE, AUTOTUNE)
test_ds = utils.make_ts_ds(test_df, classes, BATCH_SIZE, AUTOTUNE)
# Out:
# D:\sentiment-analysis\sentiment\utils.py:568: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(classes, rotation=45, ha='right')

# %%
from sentiment import bert_model

BERT_MODEL = 'small_bert/bert_en_uncased_L-2_H-128_A-2'


model = bert_model.BertSentimentModel(BERT_MODEL, dropout_rate=0.4,
                                      dense_units=256, classes=classes)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
from official.nlp import optimization  # to create AdamW optimizer
import tensorflow as tf
from tensorflow.keras.losses import BinaryCrossentropy


THRESHOLD = 0.5
EPOCHS = 10
INIT_LR = 3e-4


steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
num_train_steps = steps_per_epoch * EPOCHS
num_warmup_steps = int(0.1*num_train_steps)
optimizer = optimization.create_optimizer(init_lr=INIT_LR,
                                          num_train_steps=num_train_steps,
                                          num_warmup_steps=num_warmup_steps,
                                          optimizer_type='adamw')
metrics = utils.create_metrics(classes, THRESHOLD)
loss = BinaryCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
from tensorflow.keras.callbacks import EarlyStopping


history = model.fit(x=train_ds, validation_data=val_ds, epochs=EPOCHS,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=2)])
# Out:
# Epoch 1/10
# 463/463 [==============================] - 617s 1s/step - loss: 0.3126 - precision@0.5/admiration: 0.1465 - recall@0.5/admiration: 0.1100 - precision@0.5/amusement: 0.0799 - recall@0.5/amusement: 0.0466 - precision@0.5/anger: 0.0511 - recall@0.5/anger: 0.0606 - precision@0.5/annoyance: 0.0905 - recall@0.5/annoyance: 0.0304 - precision@0.5/approval: 0.0886 - recall@0.5/approval: 0.0124 - precision@0.5/caring: 0.0401 - recall@0.5/caring: 0.1713 - precision@0.5/confusion: 0.0435 - recall@0.5/confusion: 0.0278 - precision@0.5/curiosity: 0.0828 - recall@0.5/curiosity: 0.1794 - precision@0.5/desire: 0.0189 - recall@0.5/desire: 0.0723 - precision@0.5/disappointment: 0.0414 - recall@0.5/disappointment: 0.0370 - precision@0.5/disapproval: 0.0628 - recall@0.5/disapproval: 0.0714 - precision@0.5/disgust: 0.0173 - recall@0.5/disgust: 0.0780 - precision@0.5/embarrassment: 0.0156 - recall@0.5/embarrassment: 0.1163 - precision@0.5/excitement: 0.0194 - recall@0.5/excitement: 0.1280 - precision@0.5/fear: 0.0170 - recall@0.5/fear: 0.1028 - precision@0.5/gratitude: 0.0986 - recall@0.5/gratitude: 0.1884 - precision@0.5/grief: 0.0199 - recall@0.5/grief: 0.2091 - precision@0.5/joy: 0.0382 - recall@0.5/joy: 0.0222 - precision@0.5/love: 0.1325 - recall@0.5/love: 0.0447 - precision@0.5/nervousness: 0.0163 - recall@0.5/nervousness: 0.0450 - precision@0.5/optimism: 0.0640 - recall@0.5/optimism: 0.0312 - precision@0.5/pride: 0.0160 - recall@0.5/pride: 0.1036 - precision@0.5/realization: 0.0353 - recall@0.5/realization: 0.1463 - precision@0.5/relief: 0.0186 - recall@0.5/relief: 0.1129 - precision@0.5/remorse: 0.0086 - recall@0.5/remorse: 0.0298 - precision@0.5/sadness: 0.0487 - recall@0.5/sadness: 0.0778 - precision@0.5/surprise: 0.0362 - recall@0.5/surprise: 0.0660 - precision@0.5/all: 0.0461 - recall@0.5/all: 0.0824 - f1_score@0.5/all: 0.0634 - f1_score_micro@0.5/all: 0.0591 - f1_score_macro@0.5/all: 0.0495 - val_loss: 0.1462 - val_precision@0.5/admiration: 0.0000e+00 - val_recall@0.5/admiration: 0.0000e+00 - val_precision@0.5/amusement: 0.0000e+00 - val_recall@0.5/amusement: 0.0000e+00 - val_precision@0.5/anger: 0.0000e+00 - val_recall@0.5/anger: 0.0000e+00 - val_precision@0.5/annoyance: 0.0000e+00 - val_recall@0.5/annoyance: 0.0000e+00 - val_precision@0.5/approval: 0.0000e+00 - val_recall@0.5/approval: 0.0000e+00 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.0000e+00 - val_recall@0.5/curiosity: 0.0000e+00 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.0000e+00 - val_recall@0.5/disapproval: 0.0000e+00 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9802 - val_recall@0.5/gratitude: 0.7810 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.0000e+00 - val_recall@0.5/joy: 0.0000e+00 - val_precision@0.5/love: 0.8421 - val_recall@0.5/love: 0.0478 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.0000e+00 - val_recall@0.5/optimism: 0.0000e+00 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.0000e+00 - val_recall@0.5/remorse: 0.0000e+00 - val_precision@0.5/sadness: 0.0000e+00 - val_recall@0.5/sadness: 0.0000e+00 - val_precision@0.5/surprise: 0.0 ...
# Epoch 2/10
# 463/463 [==============================] - 564s 1s/step - loss: 0.1480 - precision@0.5/admiration: 0.6631 - recall@0.5/admiration: 0.3753 - precision@0.5/amusement: 0.7646 - recall@0.5/amusement: 0.5027 - precision@0.5/anger: 0.5000 - recall@0.5/anger: 0.0613 - precision@0.5/annoyance: 0.2654 - recall@0.5/annoyance: 0.0179 - precision@0.5/approval: 0.3194 - recall@0.5/approval: 0.0162 - precision@0.5/caring: 0.2500 - recall@0.5/caring: 9.2081e-04 - precision@0.5/confusion: 0.2300 - recall@0.5/confusion: 0.0178 - precision@0.5/curiosity: 0.6019 - recall@0.5/curiosity: 0.3555 - precision@0.5/desire: 0.5000 - recall@0.5/desire: 0.0039 - precision@0.5/disappointment: 0.0000e+00 - recall@0.5/disappointment: 0.0000e+00 - precision@0.5/disapproval: 0.3011 - recall@0.5/disapproval: 0.0142 - precision@0.5/disgust: 0.0000e+00 - recall@0.5/disgust: 0.0000e+00 - precision@0.5/embarrassment: 0.5000 - recall@0.5/embarrassment: 0.0039 - precision@0.5/excitement: 0.0000e+00 - recall@0.5/excitement: 0.0000e+00 - precision@0.5/fear: 0.2308 - recall@0.5/fear: 0.0059 - precision@0.5/gratitude: 0.9148 - recall@0.5/gratitude: 0.7223 - precision@0.5/grief: 0.4333 - recall@0.5/grief: 0.0256 - precision@0.5/joy: 0.5432 - recall@0.5/joy: 0.0630 - precision@0.5/love: 0.7964 - recall@0.5/love: 0.5544 - precision@0.5/nervousness: 0.3846 - recall@0.5/nervousness: 0.0094 - precision@0.5/optimism: 0.7036 - recall@0.5/optimism: 0.1373 - precision@0.5/pride: 0.7143 - recall@0.5/pride: 0.0199 - precision@0.5/realization: 0.0000e+00 - recall@0.5/realization: 0.0000e+00 - precision@0.5/relief: 0.0000e+00 - recall@0.5/relief: 0.0000e+00 - precision@0.5/remorse: 0.5789 - recall@0.5/remorse: 0.0218 - precision@0.5/sadness: 0.5411 - recall@0.5/sadness: 0.0778 - precision@0.5/surprise: 0.4750 - recall@0.5/surprise: 0.0184 - precision@0.5/all: 0.7124 - recall@0.5/all: 0.1916 - f1_score@0.5/all: 0.2407 - f1_score_micro@0.5/all: 0.3020 - f1_score_macro@0.5/all: 0.1451 - val_loss: 0.1106 - val_precision@0.5/admiration: 0.8008 - val_recall@0.5/admiration: 0.5634 - val_precision@0.5/amusement: 0.7980 - val_recall@0.5/amusement: 0.8466 - val_precision@0.5/anger: 0.6124 - val_recall@0.5/anger: 0.3062 - val_precision@0.5/annoyance: 0.6667 - val_recall@0.5/annoyance: 0.0098 - val_precision@0.5/approval: 0.7826 - val_recall@0.5/approval: 0.0372 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.0000e+00 - val_recall@0.5/confusion: 0.0000e+00 - val_precision@0.5/curiosity: 0.6206 - val_recall@0.5/curiosity: 0.6977 - val_precision@0.5/desire: 0.0000e+00 - val_recall@0.5/desire: 0.0000e+00 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.0000e+00 - val_recall@0.5/disapproval: 0.0000e+00 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.0000e+00 - val_recall@0.5/embarrassment: 0.0000e+00 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.0000e+00 - val_recall@0.5/fear: 0.0000e+00 - val_precision@0.5/gratitude: 0.9478 - val_recall@0.5/gratitude: 0.8600 - val_precision@0.5/grief: 0.0000e+00 - val_recall@0.5/grief: 0.0000e+00 - val_precision@0.5/joy: 0.6500 - val_recall@0.5/joy: 0.2778 - val_precision@0.5/love: 0.8406 - val_recall@0.5/love: 0.6925 - val_precision@0.5/nervousness: 0.0000e+00 - val_recall@0.5/nervousness: 0.0000e+00 - val_precision@0.5/optimism: 0.7325 - val_recall@0.5/optimism: 0.4475 - val_precision@0.5/pride: 0.0000e+00 - val_recall@0.5/pride: 0.0000e+00 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.0000e+00 - val_recall@0.5/remorse: 0.0000e+00 - val_precision@0.5/sadness: 0.6040 - val_recall@0.5/sadness: 0.4306 - val_precision@0.5/surprise: 0.7273 - val_recall@0.5/surpris ...
# Epoch 3/10
# 463/463 [==============================] - 577s 1s/step - loss: 0.1246 - precision@0.5/admiration: 0.7351 - recall@0.5/admiration: 0.5388 - precision@0.5/amusement: 0.7983 - recall@0.5/amusement: 0.6986 - precision@0.5/anger: 0.5665 - recall@0.5/anger: 0.2096 - precision@0.5/annoyance: 0.3833 - recall@0.5/annoyance: 0.0746 - precision@0.5/approval: 0.4766 - recall@0.5/approval: 0.0576 - precision@0.5/caring: 0.1500 - recall@0.5/caring: 0.0028 - precision@0.5/confusion: 0.2965 - recall@0.5/confusion: 0.0456 - precision@0.5/curiosity: 0.6387 - recall@0.5/curiosity: 0.4560 - precision@0.5/desire: 0.5312 - recall@0.5/desire: 0.0332 - precision@0.5/disappointment: 0.2143 - recall@0.5/disappointment: 0.0024 - precision@0.5/disapproval: 0.4169 - recall@0.5/disapproval: 0.0648 - precision@0.5/disgust: 0.3333 - recall@0.5/disgust: 0.0080 - precision@0.5/embarrassment: 0.7222 - recall@0.5/embarrassment: 0.0252 - precision@0.5/excitement: 0.3333 - recall@0.5/excitement: 0.0020 - precision@0.5/fear: 0.6757 - recall@0.5/fear: 0.0988 - precision@0.5/gratitude: 0.9266 - recall@0.5/gratitude: 0.8252 - precision@0.5/grief: 0.7214 - recall@0.5/grief: 0.1992 - precision@0.5/joy: 0.5588 - recall@0.5/joy: 0.2042 - precision@0.5/love: 0.8013 - recall@0.5/love: 0.6885 - precision@0.5/nervousness: 0.7231 - recall@0.5/nervousness: 0.0882 - precision@0.5/optimism: 0.6873 - recall@0.5/optimism: 0.3172 - precision@0.5/pride: 0.8250 - recall@0.5/pride: 0.1315 - precision@0.5/realization: 0.2500 - recall@0.5/realization: 0.0019 - precision@0.5/relief: 1.0000 - recall@0.5/relief: 0.0020 - precision@0.5/remorse: 0.5569 - recall@0.5/remorse: 0.1845 - precision@0.5/sadness: 0.6350 - recall@0.5/sadness: 0.2597 - precision@0.5/surprise: 0.5905 - recall@0.5/surprise: 0.1330 - precision@0.5/all: 0.7168 - recall@0.5/all: 0.2907 - f1_score@0.5/all: 0.3498 - f1_score_micro@0.5/all: 0.4137 - f1_score_macro@0.5/all: 0.2537 - val_loss: 0.1043 - val_precision@0.5/admiration: 0.8258 - val_recall@0.5/admiration: 0.5664 - val_precision@0.5/amusement: 0.7849 - val_recall@0.5/amusement: 0.8783 - val_precision@0.5/anger: 0.5584 - val_recall@0.5/anger: 0.5000 - val_precision@0.5/annoyance: 0.4933 - val_recall@0.5/annoyance: 0.1814 - val_precision@0.5/approval: 0.6087 - val_recall@0.5/approval: 0.1446 - val_precision@0.5/caring: 0.0000e+00 - val_recall@0.5/caring: 0.0000e+00 - val_precision@0.5/confusion: 0.7500 - val_recall@0.5/confusion: 0.0688 - val_precision@0.5/curiosity: 0.6577 - val_recall@0.5/curiosity: 0.6186 - val_precision@0.5/desire: 0.7727 - val_recall@0.5/desire: 0.1683 - val_precision@0.5/disappointment: 0.0000e+00 - val_recall@0.5/disappointment: 0.0000e+00 - val_precision@0.5/disapproval: 0.8276 - val_recall@0.5/disapproval: 0.0714 - val_precision@0.5/disgust: 0.0000e+00 - val_recall@0.5/disgust: 0.0000e+00 - val_precision@0.5/embarrassment: 0.6500 - val_recall@0.5/embarrassment: 0.2826 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.6842 - val_recall@0.5/fear: 0.2626 - val_precision@0.5/gratitude: 0.9416 - val_recall@0.5/gratitude: 0.8736 - val_precision@0.5/grief: 0.1667 - val_recall@0.5/grief: 0.2222 - val_precision@0.5/joy: 0.6603 - val_recall@0.5/joy: 0.4402 - val_precision@0.5/love: 0.7944 - val_recall@0.5/love: 0.8537 - val_precision@0.5/nervousness: 0.5833 - val_recall@0.5/nervousness: 0.2917 - val_precision@0.5/optimism: 0.7235 - val_recall@0.5/optimism: 0.4786 - val_precision@0.5/pride: 0.4444 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.0000e+00 - val_recall@0.5/realization: 0.0000e+00 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6585 - val_recall@0.5/remorse: 0.6429 - val_precision@0.5/sadness: 0.5628 - val_recall@0.5/sadness: 0.5359 - val_precision@0.5/surprise: 0.6103 - val_recall@0.5/surprise: 0.4826 - val_precision@0.5/all: 0.7262 - val_recall@0.5/all: 0.4105 - val_f1_score@0.5/all: 0.4555 - val_f1_score ...
# Epoch 4/10
# 463/463 [==============================] - 560s 1s/step - loss: 0.1112 - precision@0.5/admiration: 0.7688 - recall@0.5/admiration: 0.6071 - precision@0.5/amusement: 0.8120 - recall@0.5/amusement: 0.7389 - precision@0.5/anger: 0.5764 - recall@0.5/anger: 0.2999 - precision@0.5/annoyance: 0.4207 - recall@0.5/annoyance: 0.1171 - precision@0.5/approval: 0.6026 - recall@0.5/approval: 0.1328 - precision@0.5/caring: 0.5072 - recall@0.5/caring: 0.0322 - precision@0.5/confusion: 0.4375 - recall@0.5/confusion: 0.0919 - precision@0.5/curiosity: 0.6634 - recall@0.5/curiosity: 0.5121 - precision@0.5/desire: 0.7246 - recall@0.5/desire: 0.0977 - precision@0.5/disappointment: 0.4000 - recall@0.5/disappointment: 0.0220 - precision@0.5/disapproval: 0.5349 - recall@0.5/disapproval: 0.1357 - precision@0.5/disgust: 0.7083 - recall@0.5/disgust: 0.0680 - precision@0.5/embarrassment: 0.8300 - recall@0.5/embarrassment: 0.1609 - precision@0.5/excitement: 0.6667 - recall@0.5/excitement: 0.0120 - precision@0.5/fear: 0.7260 - recall@0.5/fear: 0.2984 - precision@0.5/gratitude: 0.9259 - recall@0.5/gratitude: 0.8404 - precision@0.5/grief: 0.8456 - recall@0.5/grief: 0.4753 - precision@0.5/joy: 0.5824 - recall@0.5/joy: 0.2837 - precision@0.5/love: 0.8112 - recall@0.5/love: 0.7119 - precision@0.5/nervousness: 0.7500 - recall@0.5/nervousness: 0.2758 - precision@0.5/optimism: 0.7181 - recall@0.5/optimism: 0.3611 - precision@0.5/pride: 0.8564 - recall@0.5/pride: 0.3088 - precision@0.5/realization: 0.6176 - recall@0.5/realization: 0.0194 - precision@0.5/relief: 0.2500 - recall@0.5/relief: 0.0059 - precision@0.5/remorse: 0.6022 - recall@0.5/remorse: 0.3333 - precision@0.5/sadness: 0.6817 - recall@0.5/sadness: 0.3569 - precision@0.5/surprise: 0.7035 - recall@0.5/surprise: 0.2903 - precision@0.5/all: 0.7317 - recall@0.5/all: 0.3564 - f1_score@0.5/all: 0.4272 - f1_score_micro@0.5/all: 0.4793 - f1_score_macro@0.5/all: 0.3568 - val_loss: 0.1025 - val_precision@0.5/admiration: 0.7627 - val_recall@0.5/admiration: 0.6209 - val_precision@0.5/amusement: 0.8159 - val_recall@0.5/amusement: 0.8677 - val_precision@0.5/anger: 0.5000 - val_recall@0.5/anger: 0.5426 - val_precision@0.5/annoyance: 0.4654 - val_recall@0.5/annoyance: 0.2475 - val_precision@0.5/approval: 0.5178 - val_recall@0.5/approval: 0.2107 - val_precision@0.5/caring: 0.5714 - val_recall@0.5/caring: 0.0444 - val_precision@0.5/confusion: 0.5614 - val_recall@0.5/confusion: 0.1468 - val_precision@0.5/curiosity: 0.6775 - val_recall@0.5/curiosity: 0.6469 - val_precision@0.5/desire: 0.7500 - val_recall@0.5/desire: 0.3267 - val_precision@0.5/disappointment: 0.3571 - val_recall@0.5/disappointment: 0.0485 - val_precision@0.5/disapproval: 0.5612 - val_recall@0.5/disapproval: 0.2321 - val_precision@0.5/disgust: 0.8095 - val_recall@0.5/disgust: 0.1269 - val_precision@0.5/embarrassment: 0.5938 - val_recall@0.5/embarrassment: 0.4130 - val_precision@0.5/excitement: 0.0000e+00 - val_recall@0.5/excitement: 0.0000e+00 - val_precision@0.5/fear: 0.6438 - val_recall@0.5/fear: 0.4747 - val_precision@0.5/gratitude: 0.9415 - val_recall@0.5/gratitude: 0.8713 - val_precision@0.5/grief: 0.2000 - val_recall@0.5/grief: 0.3333 - val_precision@0.5/joy: 0.6579 - val_recall@0.5/joy: 0.4274 - val_precision@0.5/love: 0.7739 - val_recall@0.5/love: 0.8687 - val_precision@0.5/nervousness: 0.5882 - val_recall@0.5/nervousness: 0.4167 - val_precision@0.5/optimism: 0.6961 - val_recall@0.5/optimism: 0.5525 - val_precision@0.5/pride: 0.4444 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.3333 - val_recall@0.5/realization: 0.0056 - val_precision@0.5/relief: 0.0000e+00 - val_recall@0.5/relief: 0.0000e+00 - val_precision@0.5/remorse: 0.6747 - val_recall@0.5/remorse: 0.6667 - val_precision@0.5/sadness: 0.5567 - val_recall@0.5/sadness: 0.5407 - val_precision@0.5/surprise: 0.6054 - val_recall@0.5/surprise: 0.5174 - val_precision@0.5/all: 0.6878 - val_recall@0.5/all: 0.4598 - val_f1_score@0.5/all: 0.5024 - val_f1_score_micro@0.5/all: 0.5511 - val_f1_ ...
# Epoch 5/10
# 463/463 [==============================] - 560s 1s/step - loss: 0.1015 - precision@0.5/admiration: 0.8016 - recall@0.5/admiration: 0.6606 - precision@0.5/amusement: 0.8292 - recall@0.5/amusement: 0.7647 - precision@0.5/anger: 0.6157 - recall@0.5/anger: 0.3639 - precision@0.5/annoyance: 0.4724 - recall@0.5/annoyance: 0.1605 - precision@0.5/approval: 0.6521 - recall@0.5/approval: 0.2211 - precision@0.5/caring: 0.5984 - recall@0.5/caring: 0.0700 - precision@0.5/confusion: 0.5029 - recall@0.5/confusion: 0.1359 - precision@0.5/curiosity: 0.6987 - recall@0.5/curiosity: 0.5640 - precision@0.5/desire: 0.7203 - recall@0.5/desire: 0.2012 - precision@0.5/disappointment: 0.4964 - recall@0.5/disappointment: 0.0535 - precision@0.5/disapproval: 0.5605 - recall@0.5/disapproval: 0.1995 - precision@0.5/disgust: 0.6915 - recall@0.5/disgust: 0.1300 - precision@0.5/embarrassment: 0.8324 - recall@0.5/embarrassment: 0.2791 - precision@0.5/excitement: 0.7000 - recall@0.5/excitement: 0.0420 - precision@0.5/fear: 0.8084 - recall@0.5/fear: 0.4170 - precision@0.5/gratitude: 0.9338 - recall@0.5/gratitude: 0.8575 - precision@0.5/grief: 0.8847 - recall@0.5/grief: 0.6509 - precision@0.5/joy: 0.6379 - recall@0.5/joy: 0.3446 - precision@0.5/love: 0.8342 - recall@0.5/love: 0.7566 - precision@0.5/nervousness: 0.7817 - recall@0.5/nervousness: 0.4165 - precision@0.5/optimism: 0.7520 - recall@0.5/optimism: 0.4202 - precision@0.5/pride: 0.8556 - recall@0.5/pride: 0.4721 - precision@0.5/realization: 0.7284 - recall@0.5/realization: 0.0546 - precision@0.5/relief: 0.5161 - recall@0.5/relief: 0.0634 - precision@0.5/remorse: 0.6717 - recall@0.5/remorse: 0.4385 - precision@0.5/sadness: 0.6952 - recall@0.5/sadness: 0.4118 - precision@0.5/surprise: 0.7140 - recall@0.5/surprise: 0.3660 - precision@0.5/all: 0.7521 - recall@0.5/all: 0.4146 - f1_score@0.5/all: 0.4915 - f1_score_micro@0.5/all: 0.5346 - f1_score_macro@0.5/all: 0.4372 - val_loss: 0.1024 - val_precision@0.5/admiration: 0.7374 - val_recall@0.5/admiration: 0.6460 - val_precision@0.5/amusement: 0.7882 - val_recall@0.5/amusement: 0.8466 - val_precision@0.5/anger: 0.4983 - val_recall@0.5/anger: 0.5543 - val_precision@0.5/annoyance: 0.3853 - val_recall@0.5/annoyance: 0.3211 - val_precision@0.5/approval: 0.4531 - val_recall@0.5/approval: 0.2397 - val_precision@0.5/caring: 0.5625 - val_recall@0.5/caring: 0.1000 - val_precision@0.5/confusion: 0.4300 - val_recall@0.5/confusion: 0.1972 - val_precision@0.5/curiosity: 0.6676 - val_recall@0.5/curiosity: 0.6469 - val_precision@0.5/desire: 0.7609 - val_recall@0.5/desire: 0.3465 - val_precision@0.5/disappointment: 0.3529 - val_recall@0.5/disappointment: 0.0874 - val_precision@0.5/disapproval: 0.5565 - val_recall@0.5/disapproval: 0.2054 - val_precision@0.5/disgust: 0.6739 - val_recall@0.5/disgust: 0.2313 - val_precision@0.5/embarrassment: 0.6000 - val_recall@0.5/embarrassment: 0.4565 - val_precision@0.5/excitement: 1.0000 - val_recall@0.5/excitement: 0.0441 - val_precision@0.5/fear: 0.7353 - val_recall@0.5/fear: 0.5051 - val_precision@0.5/gratitude: 0.9379 - val_recall@0.5/gratitude: 0.8871 - val_precision@0.5/grief: 0.2500 - val_recall@0.5/grief: 0.3333 - val_precision@0.5/joy: 0.6707 - val_recall@0.5/joy: 0.4786 - val_precision@0.5/love: 0.7806 - val_recall@0.5/love: 0.8388 - val_precision@0.5/nervousness: 0.5500 - val_recall@0.5/nervousness: 0.4583 - val_precision@0.5/optimism: 0.6599 - val_recall@0.5/optimism: 0.5058 - val_precision@0.5/pride: 0.4000 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.7273 - val_recall@0.5/realization: 0.0444 - val_precision@0.5/relief: 0.2222 - val_recall@0.5/relief: 0.0870 - val_precision@0.5/remorse: 0.6824 - val_recall@0.5/remorse: 0.6905 - val_precision@0.5/sadness: 0.6057 - val_recall@0.5/sadness: 0.5072 - val_precision@0.5/surprise: 0.6154 - val_recall@0.5/surprise: 0.5581 - val_precision@0.5/all: 0.6595 - val_recall@0.5/all: 0.4784 - val_f1_score@0.5/all: 0.5181 - val_f1_score_micro@0.5/all: 0.5545 - val_f1_score_macro@0.5/ ...
# Epoch 6/10
# 463/463 [==============================] - 561s 1s/step - loss: 0.0940 - precision@0.5/admiration: 0.8146 - recall@0.5/admiration: 0.6898 - precision@0.5/amusement: 0.8486 - recall@0.5/amusement: 0.7887 - precision@0.5/anger: 0.6463 - recall@0.5/anger: 0.4272 - precision@0.5/annoyance: 0.5172 - recall@0.5/annoyance: 0.2188 - precision@0.5/approval: 0.7117 - recall@0.5/approval: 0.2974 - precision@0.5/caring: 0.6535 - recall@0.5/caring: 0.1372 - precision@0.5/confusion: 0.5221 - recall@0.5/confusion: 0.1730 - precision@0.5/curiosity: 0.7137 - recall@0.5/curiosity: 0.5731 - precision@0.5/desire: 0.7759 - recall@0.5/desire: 0.2637 - precision@0.5/disappointment: 0.5550 - recall@0.5/disappointment: 0.0874 - precision@0.5/disapproval: 0.6292 - recall@0.5/disapproval: 0.2749 - precision@0.5/disgust: 0.6839 - recall@0.5/disgust: 0.2120 - precision@0.5/embarrassment: 0.8043 - recall@0.5/embarrassment: 0.3585 - precision@0.5/excitement: 0.5370 - recall@0.5/excitement: 0.0580 - precision@0.5/fear: 0.7957 - recall@0.5/fear: 0.5079 - precision@0.5/gratitude: 0.9411 - recall@0.5/gratitude: 0.8613 - precision@0.5/grief: 0.9035 - recall@0.5/grief: 0.7199 - precision@0.5/joy: 0.6551 - recall@0.5/joy: 0.3797 - precision@0.5/love: 0.8412 - recall@0.5/love: 0.7591 - precision@0.5/nervousness: 0.8232 - recall@0.5/nervousness: 0.5328 - precision@0.5/optimism: 0.7484 - recall@0.5/optimism: 0.4482 - precision@0.5/pride: 0.8824 - recall@0.5/pride: 0.5677 - precision@0.5/realization: 0.6084 - recall@0.5/realization: 0.0935 - precision@0.5/relief: 0.6333 - recall@0.5/relief: 0.1505 - precision@0.5/remorse: 0.6829 - recall@0.5/remorse: 0.4742 - precision@0.5/sadness: 0.7198 - recall@0.5/sadness: 0.4674 - precision@0.5/surprise: 0.7267 - recall@0.5/surprise: 0.4621 - precision@0.5/all: 0.7632 - recall@0.5/all: 0.4596 - f1_score@0.5/all: 0.5399 - f1_score_micro@0.5/all: 0.5737 - f1_score_macro@0.5/all: 0.4954 - val_loss: 0.1041 - val_precision@0.5/admiration: 0.7513 - val_recall@0.5/admiration: 0.6327 - val_precision@0.5/amusement: 0.7680 - val_recall@0.5/amusement: 0.8757 - val_precision@0.5/anger: 0.4485 - val_recall@0.5/anger: 0.5736 - val_precision@0.5/annoyance: 0.4026 - val_recall@0.5/annoyance: 0.3039 - val_precision@0.5/approval: 0.4553 - val_recall@0.5/approval: 0.2417 - val_precision@0.5/caring: 0.5283 - val_recall@0.5/caring: 0.1556 - val_precision@0.5/confusion: 0.4234 - val_recall@0.5/confusion: 0.2156 - val_precision@0.5/curiosity: 0.6732 - val_recall@0.5/curiosity: 0.5819 - val_precision@0.5/desire: 0.7292 - val_recall@0.5/desire: 0.3465 - val_precision@0.5/disappointment: 0.3133 - val_recall@0.5/disappointment: 0.1262 - val_precision@0.5/disapproval: 0.5000 - val_recall@0.5/disapproval: 0.2738 - val_precision@0.5/disgust: 0.6600 - val_recall@0.5/disgust: 0.2463 - val_precision@0.5/embarrassment: 0.5750 - val_recall@0.5/embarrassment: 0.5000 - val_precision@0.5/excitement: 0.7647 - val_recall@0.5/excitement: 0.0956 - val_precision@0.5/fear: 0.6875 - val_recall@0.5/fear: 0.5556 - val_precision@0.5/gratitude: 0.9359 - val_recall@0.5/gratitude: 0.8894 - val_precision@0.5/grief: 0.2632 - val_recall@0.5/grief: 0.5556 - val_precision@0.5/joy: 0.6398 - val_recall@0.5/joy: 0.5085 - val_precision@0.5/love: 0.7812 - val_recall@0.5/love: 0.8418 - val_precision@0.5/nervousness: 0.4783 - val_recall@0.5/nervousness: 0.4583 - val_precision@0.5/optimism: 0.6438 - val_recall@0.5/optimism: 0.5486 - val_precision@0.5/pride: 0.4000 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.5455 - val_recall@0.5/realization: 0.0667 - val_precision@0.5/relief: 0.4545 - val_recall@0.5/relief: 0.2174 - val_precision@0.5/remorse: 0.6824 - val_recall@0.5/remorse: 0.6905 - val_precision@0.5/sadness: 0.5459 - val_recall@0.5/sadness: 0.5120 - val_precision@0.5/surprise: 0.6169 - val_recall@0.5/surprise: 0.5523 - val_precision@0.5/all: 0.6425 - val_recall@0.5/all: 0.4898 - val_f1_score@0.5/all: 0.5267 - val_f1_score_micro@0.5/all: 0.5558 - val_f1_score_macro@0.5/ ...
# Epoch 7/10
# 463/463 [==============================] - 560s 1s/step - loss: 0.0871 - precision@0.5/admiration: 0.8378 - recall@0.5/admiration: 0.7214 - precision@0.5/amusement: 0.8523 - recall@0.5/amusement: 0.7964 - precision@0.5/anger: 0.6568 - recall@0.5/anger: 0.4616 - precision@0.5/annoyance: 0.5417 - recall@0.5/annoyance: 0.2601 - precision@0.5/approval: 0.7319 - recall@0.5/approval: 0.3606 - precision@0.5/caring: 0.6910 - recall@0.5/caring: 0.1915 - precision@0.5/confusion: 0.5666 - recall@0.5/confusion: 0.2201 - precision@0.5/curiosity: 0.7526 - recall@0.5/curiosity: 0.6311 - precision@0.5/desire: 0.7578 - recall@0.5/desire: 0.3301 - precision@0.5/disappointment: 0.5669 - recall@0.5/disappointment: 0.1134 - precision@0.5/disapproval: 0.6657 - recall@0.5/disapproval: 0.3529 - precision@0.5/disgust: 0.7661 - recall@0.5/disgust: 0.2620 - precision@0.5/embarrassment: 0.8467 - recall@0.5/embarrassment: 0.4283 - precision@0.5/excitement: 0.6222 - recall@0.5/excitement: 0.1120 - precision@0.5/fear: 0.8040 - recall@0.5/fear: 0.5593 - precision@0.5/gratitude: 0.9427 - recall@0.5/gratitude: 0.8754 - precision@0.5/grief: 0.9251 - recall@0.5/grief: 0.7791 - precision@0.5/joy: 0.7057 - recall@0.5/joy: 0.4105 - precision@0.5/love: 0.8381 - recall@0.5/love: 0.7759 - precision@0.5/nervousness: 0.8626 - recall@0.5/nervousness: 0.6360 - precision@0.5/optimism: 0.7767 - recall@0.5/optimism: 0.4755 - precision@0.5/pride: 0.8840 - recall@0.5/pride: 0.6375 - precision@0.5/realization: 0.6947 - recall@0.5/realization: 0.1454 - precision@0.5/relief: 0.7229 - recall@0.5/relief: 0.2376 - precision@0.5/remorse: 0.7107 - recall@0.5/remorse: 0.5655 - precision@0.5/sadness: 0.7546 - recall@0.5/sadness: 0.5125 - precision@0.5/surprise: 0.7525 - recall@0.5/surprise: 0.5019 - precision@0.5/all: 0.7799 - recall@0.5/all: 0.5024 - f1_score@0.5/all: 0.5831 - f1_score_micro@0.5/all: 0.6111 - f1_score_macro@0.5/all: 0.5474 - val_loss: 0.1053 - val_precision@0.5/admiration: 0.7527 - val_recall@0.5/admiration: 0.6239 - val_precision@0.5/amusement: 0.7796 - val_recall@0.5/amusement: 0.8704 - val_precision@0.5/anger: 0.4653 - val_recall@0.5/anger: 0.5465 - val_precision@0.5/annoyance: 0.3892 - val_recall@0.5/annoyance: 0.3186 - val_precision@0.5/approval: 0.4203 - val_recall@0.5/approval: 0.2562 - val_precision@0.5/caring: 0.5517 - val_recall@0.5/caring: 0.1778 - val_precision@0.5/confusion: 0.4307 - val_recall@0.5/confusion: 0.2706 - val_precision@0.5/curiosity: 0.6845 - val_recall@0.5/curiosity: 0.6130 - val_precision@0.5/desire: 0.7021 - val_recall@0.5/desire: 0.3267 - val_precision@0.5/disappointment: 0.3168 - val_recall@0.5/disappointment: 0.1553 - val_precision@0.5/disapproval: 0.4810 - val_recall@0.5/disapproval: 0.3006 - val_precision@0.5/disgust: 0.6667 - val_recall@0.5/disgust: 0.2687 - val_precision@0.5/embarrassment: 0.5349 - val_recall@0.5/embarrassment: 0.5000 - val_precision@0.5/excitement: 0.6000 - val_recall@0.5/excitement: 0.0882 - val_precision@0.5/fear: 0.7037 - val_recall@0.5/fear: 0.5758 - val_precision@0.5/gratitude: 0.9489 - val_recall@0.5/gratitude: 0.8804 - val_precision@0.5/grief: 0.2353 - val_recall@0.5/grief: 0.4444 - val_precision@0.5/joy: 0.6122 - val_recall@0.5/joy: 0.5128 - val_precision@0.5/love: 0.7729 - val_recall@0.5/love: 0.8328 - val_precision@0.5/nervousness: 0.4500 - val_recall@0.5/nervousness: 0.3750 - val_precision@0.5/optimism: 0.6602 - val_recall@0.5/optimism: 0.5292 - val_precision@0.5/pride: 0.3636 - val_recall@0.5/pride: 0.2353 - val_precision@0.5/realization: 0.4857 - val_recall@0.5/realization: 0.0944 - val_precision@0.5/relief: 0.3333 - val_recall@0.5/relief: 0.1739 - val_precision@0.5/remorse: 0.6848 - val_recall@0.5/remorse: 0.7500 - val_precision@0.5/sadness: 0.5388 - val_recall@0.5/sadness: 0.5311 - val_precision@0.5/surprise: 0.5799 - val_recall@0.5/surprise: 0.5698 - val_precision@0.5/all: 0.6322 - val_recall@0.5/all: 0.4971 - val_f1_score@0.5/all: 0.5327 - val_f1_score_micro@0.5/all: 0.5566 - val_f1_score_macro@0.5/ ...

# %%
eval_metrics = model.evaluate(x=test_ds, return_dict=True)
utils.print_metrics(eval_metrics)
# Out:
# 73/73 [==============================] - 22s 300ms/step - loss: 0.0902 - precision@0.5/admiration: 0.6925 - recall@0.5/admiration: 0.7004 - precision@0.5/amusement: 0.7608 - recall@0.5/amusement: 0.8899 - precision@0.5/anger: 0.4492 - recall@0.5/anger: 0.5721 - precision@0.5/annoyance: 0.3333 - recall@0.5/annoyance: 0.2973 - precision@0.5/approval: 0.4613 - recall@0.5/approval: 0.3504 - precision@0.5/caring: 0.6230 - recall@0.5/caring: 0.2815 - precision@0.5/confusion: 0.4094 - recall@0.5/confusion: 0.3506 - precision@0.5/curiosity: 0.5951 - recall@0.5/curiosity: 0.6904 - precision@0.5/desire: 0.6512 - recall@0.5/desire: 0.3544 - precision@0.5/disappointment: 0.3544 - recall@0.5/disappointment: 0.1944 - precision@0.5/disapproval: 0.4923 - recall@0.5/disapproval: 0.3299 - precision@0.5/disgust: 0.7115 - recall@0.5/disgust: 0.3737 - precision@0.5/embarrassment: 0.6875 - recall@0.5/embarrassment: 0.5641 - precision@0.5/excitement: 0.6250 - recall@0.5/excitement: 0.1546 - precision@0.5/fear: 0.7424 - recall@0.5/fear: 0.5632 - precision@0.5/gratitude: 0.9205 - recall@0.5/gratitude: 0.9025 - precision@0.5/grief: 0.2778 - recall@0.5/grief: 0.6250 - precision@0.5/joy: 0.5856 - recall@0.5/joy: 0.6424 - precision@0.5/love: 0.7257 - recall@0.5/love: 0.9111 - precision@0.5/nervousness: 0.3125 - recall@0.5/nervousness: 0.2941 - precision@0.5/optimism: 0.6095 - recall@0.5/optimism: 0.6023 - precision@0.5/pride: 0.4286 - recall@0.5/pride: 0.8182 - precision@0.5/realization: 0.6585 - recall@0.5/realization: 0.2143 - precision@0.5/relief: 0.1000 - recall@0.5/relief: 0.0588 - precision@0.5/remorse: 0.5732 - recall@0.5/remorse: 0.7121 - precision@0.5/sadness: 0.4372 - recall@0.5/sadness: 0.5912 - precision@0.5/surprise: 0.5283 - recall@0.5/surprise: 0.5957 - precision@0.5/all: 0.5999 - recall@0.5/all: 0.5592 - f1_score@0.5/all: 0.5616 - f1_score_micro@0.5/all: 0.5788 - f1_score_macro@0.5/all: 0.5009
# metric                          value
# ----------------------------  -------
# loss                          0.09022
# precision@0.5/admiration      0.69245
# recall@0.5/admiration         0.70038
# precision@0.5/amusement       0.76075
# recall@0.5/amusement          0.88994
# precision@0.5/anger           0.44922
# recall@0.5/anger              0.57214
# precision@0.5/annoyance       0.33333
# recall@0.5/annoyance          0.29730
# precision@0.5/approval        0.46128
# recall@0.5/approval           0.35038
# precision@0.5/caring          0.62295
# recall@0.5/caring             0.28148
# precision@0.5/confusion       0.40940
# recall@0.5/confusion          0.35057
# precision@0.5/curiosity       0.59509
# recall@0.5/curiosity          0.69039
# precision@0.5/desire          0.65116
# recall@0.5/desire             0.35443
# precision@0.5/disappointment  0.35443
# recall@0.5/disappointment     0.19444
# precision@0.5/disapproval     0.49231
# recall@0.5/disapproval        0.32990
# precision@0.5/disgust         0.71154
# recall@0.5/disgust            0.37374
# precision@0.5/embarrassment   0.68750
# recall@0.5/embarrassment      0.56410
# precision@0.5/excitement      0.62500
# recall@0.5/excitement         0.15464
# precision@0.5/fear            0.74242
# recall@0.5/fear               0.56322
# precision@0.5/gratitude       0.92045
# recall@0.5/gratitude          0.90251
# precision@0.5/grief           0.27778
# recall@0.5/grief              0.62500
# precision@0.5/joy             0.58564
# recall@0.5/joy                0.64242
# precision@0.5/love            0.72566
# recall@0.5/love               0.91111
# precision@0.5/nervousness     0.31250
# recall@0.5/nervousness        0.29412
# precision@0.5/optimism        0.60947
# recall@0.5/optimism           0.60234
# precision@0.5/pride           0.42857
# recall@0.5/pride              0.81818
# precision@0.5/realization     0.65854
# recall@0.5/realization        0.21429
# precision@0.5/relief          0.10000
# recall@0.5/relief             0.05882
# precision@0.5/remorse         0.57317
# recall@0.5/remorse            0.71212
# precision@0.5/sadness         0.43721
# recall@0.5/sadness            0.59119
# precision@0.5/surprise        0.52830
# recall@0.5/surprise           0.59574
# precision@0.5/all             0.59991
# recall@0.5/all                0.55915
# f1_score@0.5/all              0.56160
# f1_score_micro@0.5/all        0.57881
# f1_score_macro@0.5/all        0.50088

# %%
stats = history.history
train_stats = {
    'Train Loss': stats['loss'],
    'Train Precision All': stats['precision@0.5/all'],
    'Train Recall All': stats['recall@0.5/all'],
    'Train F1-Score Weighted': stats['f1_score@0.5/all'],
    'Train F1-Score Micro': stats['f1_score_micro@0.5/all'],
    'Train F1-Score Macro': stats['f1_score_macro@0.5/all'],
}

utils.plot_history(train_stats, title='Model fit history (train)')

# %%
val_stats = {
    'Val Loss': stats['val_loss'],
    'Val Precision All': stats['val_precision@0.5/all'],
    'Val Recall All': stats['val_recall@0.5/all'],
    'Val F1-Score Weighted': stats['val_f1_score@0.5/all'],
    'Val F1-Score Micro': stats['val_f1_score_micro@0.5/all'],
    'Val F1-Score Macro': stats['val_f1_score_macro@0.5/all'],
}
utils.plot_history(val_stats, title='Model fit history (validation)')

# %% [markdown]
# ## Score test and run most-important metrics on emotions prediction

# %%
from tensorflow.keras.metrics import Precision
from tensorflow_addons.metrics import F1Score


test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(classes), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(), THRESHOLD)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.5999
# F1-Score (micro): 0.5788
# F1-Score (macro): 0.5009

# %% [markdown]
# ## Score test and run most-important metrics on sentiments prediction

# %%
sentiments = utils.load_sentiments(DATASET_DIR)
sentiment_map = utils.map_sentiments(classes, sentiments)
del sentiment_map[27]
test_metrics = {
    'TP Rate (precision)': Precision(),
    'F1-Score (micro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='micro'),
    'F1-Score (macro)': F1Score(num_classes=len(sentiments), threshold=THRESHOLD, average='macro'),
}
utils.score_test(test_ds, model, test_metrics.values(),
                           THRESHOLD, sentiment_map)
for name, metric in test_metrics.items():
    print('{}: {:.4f}'.format(name, metric.result().numpy()))
# Out:
# TP Rate (precision): 0.8479
# F1-Score (micro): 0.7754
# F1-Score (macro): 0.7400

# %%
utils.test_examples(model, classes)
# Out:
# I am feeling great today!: admiration 👏
# The weather is so good: admiration 👏
# I have performed well at the university:
# The war has started:
# He is desperate in this cruel world:
# I love the feeling when my girlfriend hugs me: love ❤️
# I hate monday mornings: anger 😡
# Merry Christmas! I told Santa you were good this year and asked him to bring you a year full of joy and pleasure : joy 😃
# brilliant! Such a detailed review, it was a pleasure, thank you! Guys, make sure you find time to read :) Aaaaand you can actually choose sth new): admiration 👏 gratitude 🙏
# I have the new pan for pancakes.: approval 👍
# Relax, bro. Take it easy: relief 😅
# WTF? Are they kidding us? I'm gonna argue with the manager!:
# OMG, yep!!! That is the final answer! Thank you so much!: gratitude 🙏
# I am so glad this is over: joy 😃
# Sorry, I feel bad for having said that: remorse 😔 sadness 😞
# Happy birthday, my friend! I wish you a lot of success!: joy 😃
# What a shame! I will never talk to him: embarrassment 😳
# What if she knows? We don't know what to do: confusion 😕 curiosity 🤔
# WOW! I am really into cinema: surprise 😲
# What if I don't pass the exam? I will never get this driving license!: confusion 😕 curiosity 🤔
# I miss my grandad. I am feeling so lonely after her death. I just lost my closest person..: sadness 😞
# Skipping lessons is so miserable for Oxford stundets!:
# Have a rest, my boy. You had a long trip. I will make us tea and bring a cake.:
# What a man! My son got the highest rate and will study in Cambridge. Our family is so proud of him!: admiration 👏 pride 😌
# Mmmm, delicious. That's totally the best pasta in Italy!: admiration 👏

# %%
utils.plot_conf_mtrx_all(model, test_ds, classes)

# %%
utils.plot_conf_mtrx_per_class(model, test_ds, classes)

# %%
utils.plot_roc_curves(test_ds, model, classes)

# %%
model.save_weights('./models/bert_0_7_1_no_neutral')
